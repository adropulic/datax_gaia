# %% [markdown]
# # ML to find radial velocities using GALAXIA sim with Nearest Neighbors

# %%
# %matplotlib inline


import matplotlib
import matplotlib.colors as colors

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path
import sys
import gzip
import matplotlib.gridspec as gridspec
from scipy.stats import norm

matplotlib.rcParams.update({'font.family':'cmr10','font.size': 13})
matplotlib.rcParams['axes.unicode_minus']=False
matplotlib.rcParams['axes.labelsize']=15
plt.rcParams['figure.figsize']=(4,4)
plt.rcParams['figure.dpi'] = 80
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['mathtext.rm'] = 'serif'
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True

# %%
data = np.load('/tigress/ljchang/DataXGaia/data/galaxia_mock/processed_stars_reshuffled_with_pos_vel.npy')

# %%
data_cols = ['source_id', 'l', 'b', 'ra', 'dec', 'parallax', 'parallax_error', 
             'pmra', 'pmra_error', 'pmdec', 'pmdec_error', 'radial_velocity',
             'photo_g_mean_mag', 'photo_bp_mean_mag', 'photo_rp_mean_mag',
             'x','y','z','vx','vy','vz','r','phi','theta','vr','vphi','vtheta']
#could train on radial_velocity_error

# %%
data_train = pd.DataFrame(data[:32000], columns=data_cols)
data_val = pd.DataFrame(data[32001:40000], columns=data_cols)
data_test = pd.DataFrame(data[40000:50000], columns=data_cols)

# %%
data_train.head()
# Out:
#       source_id           l          b          ra        dec  parallax  \
# 0  5.061412e+17  131.353790  -3.668921   28.938131  58.147300  0.558357
# 1  4.793522e+17  146.070404  13.149321   74.581562  64.246163  1.284570
# 2  5.911549e+18  332.078064 -17.855680  269.959228 -61.602704  0.827003
# 3  4.596623e+18   55.180511  24.729351  268.481942  29.790023  0.770408
# 4  4.303083e+18   48.748230  -5.606678  295.265656  11.353417  0.478881
#
#    parallax_error     pmra  pmra_error      pmdec  ...         z          vx  \
# 0        0.025379 -2.61794    0.017121  -0.673081  ... -0.099606   59.186430
# 1        0.069426  9.32732    0.038823 -13.126400  ...  0.192094  -22.250179
# 2        0.066856  3.33253    0.037386  -6.251980  ... -0.355761   -7.266869
# 3        0.034757 -3.17662    0.020937 -20.357300  ...  0.558001  108.587009
# 4        0.022046 -2.53293    0.008481  -5.662840  ... -0.189015   87.723856
#
#            vy         vz         r         phi      theta         vr  \
# 0  214.909786  -0.599243  9.278926  171.686082  90.615062 -27.481188
# 1  189.906749   6.232524  8.641484  177.192710  88.726251  31.655268
# 2  220.743054 -24.071507  7.012840 -175.586689  92.907859  -8.507313
# 3  160.244402 -19.909387  7.411502  172.474670  85.682199 -87.918403
# 4  233.675764  -2.739426  6.813941  166.738898  91.589557 -31.693813
#
#          vphi     vtheta
# 0 -221.209388   0.894295
# 1 -188.589101  -5.530217
# 2 -220.647719  24.534673
# 3 -173.085269  13.327967
# 4 -247.567647   3.619987
#
# [5 rows x 27 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy.interpolate import interp1d

# %%
SS = StandardScaler()
data_train_scaled = SS.fit_transform(data_train)
data_val_scaled = SS.transform(data_val)
data_test_scaled = SS.transform(data_test)

# %%
data_train_scaled = pd.DataFrame(data_train_scaled, columns=data_cols)
data_val_scaled = pd.DataFrame(data_val_scaled, columns=data_cols)
data_test_scaled = pd.DataFrame(data_test_scaled, columns=data_cols)

# %%
#replacing radial velocity column with nonrescaled radial velocity 
#so no inverse_transform needed at the end
data_train_scaled = data_train_scaled.assign(radial_velocity=data_train['radial_velocity'])
data_val_scaled = data_val_scaled.assign(radial_velocity=data_val['radial_velocity'])
data_test_scaled = data_test_scaled.assign(radial_velocity=data_test['radial_velocity'])


vr_real_train = (data_train_scaled['radial_velocity']).values
vr_real_val = (data_val_scaled['radial_velocity']).values
vr_real_test = (data_test_scaled['radial_velocity']).values

# %%
#calculate the training weights
counts_train, bins_train = np.histogram(vr_real_train,bins=np.linspace(-700,700,51))
bin_centers_train = (bins_train[1:]+bins_train[:-1])/2
interp_func_train  = interp1d(bin_centers_train,(counts_train).astype('float'))
inv_weights_train = interp_func_train(vr_real_train)
weights_train = 1/inv_weights_train
weights_train = np.log(weights_train)
weights_train = weights_train - np.min(weights_train)+1
print(weights_train.shape)
print(np.transpose(weights_train))
# Out:
# (32000,)
# [1.82953549 1.01441998 1.0168563  ... 1.03799728 1.2982452  1.08025486]

# %%
#calculate the validation weights
counts_val, bins_val = np.histogram(vr_real_val,bins=np.linspace(-700,700,51))
bin_centers_val = (bins_val[1:]+bins_val[:-1])/2
interp_func_val  = interp1d(bin_centers_val,(counts_val).astype('float'))
inv_weights_val = interp_func_val(vr_real_val)
weights_val = 1/inv_weights_val
weights_val = np.log(weights_val)
weights_val = weights_val - np.min(weights_val)+1
print(weights_val.shape)
#weights = np.concatenate((weights_train,weights_val))
#print(np.shape(weights))
# Out:
# (7999,)

# %%
#making a test_weights array so I don't have to define separate class for TestLoader
weights_test = np.ones(10000)
print(np.shape(weights_test))
print(weights_test)
# Out:
# (10000,)
# [1. 1. 1. ... 1. 1. 1.]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
from keras import backend as K
from keras import callbacks as callbacks
global index

# %%
def LikelihoodLossFunction(y_true, y_pred):
    # shape of y_pred should be (nsamples, 2)
    # the first column should be the mean of the prediction
    # the second column is the confidence (number of standard deviations)
#     print y_true.shape
#     print y_pred.shape
    SIGMA = K.abs(y_pred[:, 1]) + 1e-6
    LOC = y_pred[:, 0]
    X = y_true[:, 0]
    weights = y_true[:,1]
    ARG = K.square(X - LOC) / (2 * K.square(SIGMA))
    PREFACT = K.log(K.pow(2 * np.pi * K.square(SIGMA), -0.5))
    return K.mean((ARG - PREFACT) * weights)

# %%
def ConstantLikelihoodLossFunction(y_true, y_pred):
    # shape of y_pred should be (nsamples, 2)
    # the first column should be the mean of the prediction
    # the second column is the confidence (number of standard deviations)
#     print y_true.shape
#     print y_pred.shape
    LOC = y_pred[:, 0]
    X = y_true[:, 0]
    weights = y_true[:,1]
    ARG = K.square(X - LOC) / (2.0)
    PREFACT = K.log(K.pow(2 * np.pi, -0.5))
    return K.mean((ARG - PREFACT) * weights)

# %% [markdown]
# # Two network technique to calculate the error

# %%
from sklearn.neighbors import NearestNeighbors
from keras.utils import Sequence
from keras.layers import Input, Dense, Lambda, Concatenate, Dropout, Activation, Add
from keras.models import Model
from keras.utils import plot_model
from IPython.display import clear_output
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger

# %%
class DataLoader(Sequence):
    
    def __init__(self, 
                 StarDF,  # Dataframe of the stars
                 DistanceVariables,  # column names for the combined distance
                 Features,  # Columns to output for machine learning
                 ToLearn,  # Column to learn
                 NNeighbors,
                 Weights,
                 batch_size=64, shuffle=True):
        'Initialization'
        self.df = StarDF
        self.num_neighbors = NNeighbors
        self.KNN = NearestNeighbors(n_neighbors=NNeighbors,
                                    n_jobs=-1
                                   )
        self.KNN.fit(self.df[DistanceVariables])
        dists, inds = self.KNN.kneighbors(self.df[DistanceVariables])
        self.knn_inds = inds
        self.features = Features
        self.weights = Weights
        self.tolearn = ToLearn
        
        self.indexes = np.arange(len(StarDF))
        self.shuffle = shuffle
        self.batch_size = batch_size
        self.on_epoch_end()
        
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
            
    def __len__(self):
            'Denotes the number of batches per epoch'
            return int(np.ceil(len(self.indexes) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        max_ind = np.min([(index+1)*self.batch_size, len(self.df)])
        indexes = self.indexes[index*self.batch_size:max_ind]
        # Generate data
        X, y = self.__data_generation(indexes)
        return X, y

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, n_features*KNN)
        # Initialization
        Y = self.df[self.tolearn].values[list_IDs_temp]
        data = self.df[self.features].values
        X = data[self.knn_inds[list_IDs_temp]].reshape(len(list_IDs_temp), len(self.features) * self.num_neighbors)
        weights = self.weights[list_IDs_temp]
        Y = np.vstack([Y,weights])
        Y = np.transpose(Y)
        return X, Y

# %%
TrainLoader = DataLoader(StarDF=data_train_scaled,
                      DistanceVariables=['x', 'y', 'z'],
                      Features=['l', 'b', 'pmra', 'pmdec', 'parallax'],
                      ToLearn='radial_velocity',
                      NNeighbors=10,
                      Weights = weights_train,
                      batch_size=10000
                     )
ValLoader = DataLoader(StarDF=data_val_scaled,
                      DistanceVariables=['x', 'y', 'z'],
                      Features=['l', 'b', 'pmra', 'pmdec', 'parallax'],
                      ToLearn='radial_velocity',
                      NNeighbors=10,
                      Weights = weights_val,
                      batch_size=10000
                     )
TestLoader = DataLoader(StarDF=data_test_scaled,
                      DistanceVariables=['x', 'y', 'z'],
                      Features=['l', 'b', 'pmra', 'pmdec', 'parallax'],
                      ToLearn='radial_velocity',
                      NNeighbors=10,
                      Weights = weights_test,
                      batch_size=10000
                     )

# %%
x, y = TrainLoader[0]
print(x.shape)
print(y.shape)
print(y[:,0])
print(y[:,1])
# Out:
# (10000, 50)
# (10000, 2)
# [-35.79029846 -11.64949989  17.85740089 ...  -9.84782028 -58.48059845
#  -42.06389999]
# [-4.93097000e+01 -1.30418995e-02  2.32978010e+00 ... -1.62278004e+01
#  -2.94076996e+01  1.69335995e+01]
# [1.45367095 1.0024063  1.0969272  ... 1.00425697 2.14907484 1.63388523]
# [1.82953549 1.01441998 1.0168563  ... 1.03799728 1.2982452  1.08025486]

# %%
# del(inputs, MeanEst, MeanModel, ConfEst, ConfModel)
input_shape=(TrainLoader[0][0].shape[-1],)
commonInput = Input(input_shape)
MeanEst = Sequential(name="MeanModel")
MeanEst.add(Dense(30, activation='relu',input_shape=(TrainLoader[0][0].shape[-1],)))
MeanEst.add(Dropout(0.1))
MeanEst.add(Dense(30, activation='relu'))
MeanEst.add(Dropout(0.1))
MeanEst.add(Dense(10, activation='relu'))
MeanEst.add(Dropout(0.1))
MeanEst.add(Dense(10, activation='relu'))
MeanEst.add(Dense(1, activation='linear'))

ConfEst = Sequential(name="ConfModel")
ConfEst.add(Dense(30, activation='relu',input_shape=(TrainLoader[0][0].shape[-1],)))
ConfEst.add(Dropout(0.1))
ConfEst.add(Dense(30, activation='relu'))
ConfEst.add(Dropout(0.1))
ConfEst.add(Dense(30, activation='relu'))
ConfEst.add(Dropout(0.1))
ConfEst.add(Dense(30, activation='relu'))
ConfEst.add(Dense(1, activation='relu'))

out1 = MeanEst(commonInput)    
out2 = ConfEst(commonInput)    
mergedOut = Concatenate(axis=-1)([out1,out2])
CombinedModel = Model(commonInput, mergedOut)
#plot_model(CombinedModel,to_file='demo.png',show_shapes=True)

# %%
#CombinedModel.save_weights('modelsIterate/TrainingBoth_0000.hdf5')

# %%
CombinedModel.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 50)           0
# __________________________________________________________________________________________________
# MeanModel (Sequential)          (None, 1)            2891        input_1[0][0]
# __________________________________________________________________________________________________
# ConfModel (Sequential)          (None, 1)            4351        input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           MeanModel[1][0]
#                                                                  ConfModel[1][0]
# ==================================================================================================
# Total params: 7,242
# Trainable params: 7,242
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## First training iteration

# %%
CheckPoint = ModelCheckpoint('models_GALAXIA/TrainingMean_{epoch:04d}.hdf5',
                             verbose=0,
                             save_best_only=False
                            )
ES = EarlyStopping(patience=20, verbose=True, restore_best_weights=True)
RLR = ReduceLROnPlateau(patience=10, min_lr=1e-5, verbose=True)
CSV_logger = CSVLogger(filename='logs/training_mean.log', separator=',', append=False)

mycallbacks = [CheckPoint, ES, RLR, CSV_logger]
#mycallbacks = [ES, RLR]

# %%
print(TrainLoader[0][0].shape)
# Out:
# (10000, 50)

# %%
ConfEst.trainable = False
MeanEst.trainable = True
CombinedModel.compile(loss=ConstantLikelihoodLossFunction,
                      optimizer='adam'
                     )
CombinedModel.fit_generator(TrainLoader,
                            validation_data=ValLoader,
                            epochs=1000,
                            callbacks = mycallbacks
                 )
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 132ms/step - loss: 2786.8841 - val_loss: 2572.8318
# Epoch 2/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 2616.7962 - val_loss: 2571.4995
# Epoch 3/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2628.7890 - val_loss: 2569.8467
# Epoch 4/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 2631.3478 - val_loss: 2567.8508
# Epoch 5/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2580.9138 - val_loss: 2565.5051
# Epoch 6/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 2681.5539 - val_loss: 2562.8269
# Epoch 7/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 2631.6319 - val_loss: 2559.5208
# Epoch 8/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2594.2667 - val_loss: 2555.4937
# Epoch 9/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2622.6388 - val_loss: 2550.4949
# Epoch 10/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 2527.6855 - val_loss: 2544.4746
# Epoch 11/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2737.1498 - val_loss: 2537.0779
# Epoch 12/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2550.3504 - val_loss: 2528.0989
# Epoch 13/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2794.6145 - val_loss: 2517.4019
# Epoch 14/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2539.9618 - val_loss: 2504.1453
# Epoch 15/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 2752.0388 - val_loss: 2488.0264
# Epoch 16/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2536.1902 - val_loss: 2468.5850
# Epoch 17/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2586.5161 - val_loss: 2446.0857
# Epoch 18/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2489.4220 - val_loss: 2422.0876
# Epoch 19/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2496.0957 - val_loss: 2396.3579
# Epoch 20/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2461.0851 - val_loss: 2369.8342
# Epoch 21/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2403.3208 - val_loss: 2344.3340
# Epoch 22/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2386.1600 - val_loss: 2320.6633
# Epoch 23/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 2394.2652 - val_loss: 2298.5283
# Epoch 24/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2561.8059 - val_loss: 2277.0935
# Epoch 25/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2355.4130 - val_loss: 2256.5889
# Epoch 26/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2340.8099 - val_loss: 2237.3896
# Epoch 27/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2328.5707 - val_loss: 2217.9097
# Epoch 28/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2251.4302 - val_loss: 2198.4043
# Epoch 29/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2354.8400 - val_loss: 2179.3635
# Epoch 30/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2292.4283 - val_loss: 2160.5059
# Epoch 31/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2327.3850 - val_loss: 2142.6523
# Epoch 32/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2396.7707 - val_loss: 2125.9695
# Epoch 33/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2217.8257 - val_loss: 2110.8452
# Epoch 34/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2214.2214 - val_loss: 2097.5254
# Epoch 35/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2233.5613 - val_loss: 2083.9763
# Epoch 36/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2272.4029 - val_loss: 2072.2200
# Epoch 37/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2208.4615 - val_loss: 2061.1509
# Epoch 38/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2228.2108 - val_loss: 2052.8989
# Epoch 39/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2186.0219 - val_loss: 2046.1249
# Epoch 40/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2156.9463 - val_loss: 2041.0245
# Epoch 41/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2172.8152 - val_loss: 2035.5931
# Epoch 42/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2215.4680 - val_loss: 2029.8770
# Epoch 43/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2176.8752 - val_loss: 2024.6494
# Epoch 44/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2165.2859 - val_loss: 2018.4012
# Epoch 45/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2143.2069 - val_loss: 2013.4690
# Epoch 46/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2095.8093 - val_loss: 2011.2424
# Epoch 47/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2111.4966 - val_loss: 2007.7751
# Epoch 48/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2129.6720 - val_loss: 2002.0308
# Epoch 49/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2151.1339 - val_loss: 1997.3817
# Epoch 50/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2073.2382 - val_loss: 1993.1578
# Epoch 51/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2039.5987 - val_loss: 1989.7765
# Epoch 52/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2297.7479 - val_loss: 1988.2174
# Epoch 53/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2104.3887 - val_loss: 1989.1187
# Epoch 54/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2090.0668 - val_loss: 1984.0986
# Epoch 55/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 2103.7104 - val_loss: 1981.2831
# Epoch 56/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 2132.3220 - val_loss: 1978.7483
# Epoch 57/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2248.0148 - val_loss: 1975.4917
# Epoch 58/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2118.8957 - val_loss: 1972.5267
# Epoch 59/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2109.7935 - val_loss: 1970.3666
# Epoch 60/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 2152.4082 - val_loss: 1968.6521
# Epoch 61/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2081.7596 - val_loss: 1969.5922
# Epoch 62/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2080.8550 - val_loss: 1969.8687
# Epoch 63/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2111.4115 - val_loss: 1968.4733
# Epoch 64/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2235.9533 - val_loss: 1964.0006
# Epoch 65/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2048.2750 - val_loss: 1960.3815
# Epoch 66/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2038.6743 - val_loss: 1957.8817
# Epoch 67/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2102.5420 - val_loss: 1957.5256
# Epoch 68/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2122.8233 - val_loss: 1957.1565
# Epoch 69/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2120.2940 - val_loss: 1957.0314
# Epoch 70/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2061.1009 - val_loss: 1957.6313
# Epoch 71/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2088.0469 - val_loss: 1958.9995
# Epoch 72/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 2063.2977 - val_loss: 1958.2522
# Epoch 73/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2097.5048 - val_loss: 1956.3749
# Epoch 74/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2021.2743 - val_loss: 1953.2432
# Epoch 75/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2040.9257 - val_loss: 1951.5934
# Epoch 76/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2062.0310 - val_loss: 1953.5084
# Epoch 77/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2050.8173 - val_loss: 1950.8418
# Epoch 78/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2007.5262 - val_loss: 1947.4020
# Epoch 79/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2111.4398 - val_loss: 1945.4747
# Epoch 80/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2025.6581 - val_loss: 1943.1583
# Epoch 81/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2075.5682 - val_loss: 1941.1182
# Epoch 82/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2042.8079 - val_loss: 1939.8818
# Epoch 83/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2045.9320 - val_loss: 1940.7581
# Epoch 84/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2017.0154 - val_loss: 1942.6180
# Epoch 85/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2006.4389 - val_loss: 1943.5258
# Epoch 86/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2017.1167 - val_loss: 1942.4935
# Epoch 87/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2015.5064 - val_loss: 1940.3768
# Epoch 88/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2031.6389 - val_loss: 1937.2505
# Epoch 89/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 2009.9682 - val_loss: 1935.0020
# Epoch 90/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1975.3278 - val_loss: 1934.1272
# Epoch 91/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1976.0497 - val_loss: 1934.6249
# Epoch 92/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1980.1922 - val_loss: 1935.2563
# Epoch 93/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1977.7839 - val_loss: 1935.8771
# Epoch 94/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1995.1780 - val_loss: 1934.8745
# Epoch 95/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2041.4832 - val_loss: 1932.0980
# Epoch 96/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1999.5936 - val_loss: 1930.8745
# Epoch 97/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 1968.6374 - val_loss: 1929.8411
# Epoch 98/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1968.9602 - val_loss: 1927.1506
# Epoch 99/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2009.8631 - val_loss: 1926.6184
# Epoch 100/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2004.6191 - val_loss: 1927.7825
# Epoch 101/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2032.8897 - val_loss: 1930.7761
# Epoch 102/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1983.0267 - val_loss: 1930.8767
# Epoch 103/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2003.3197 - val_loss: 1926.8428
# Epoch 104/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2055.4310 - val_loss: 1923.3835
# Epoch 105/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 2005.9664 - val_loss: 1920.9091
# Epoch 106/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2007.7109 - val_loss: 1920.3734
# Epoch 107/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2045.6146 - val_loss: 1921.1587
# Epoch 108/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2027.9936 - val_loss: 1923.7505
# Epoch 109/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2014.9698 - val_loss: 1924.1249
# Epoch 110/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1989.7737 - val_loss: 1921.4089
# Epoch 111/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2019.8840 - val_loss: 1918.6527
# Epoch 112/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1983.4134 - val_loss: 1917.9662
# Epoch 113/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2010.4037 - val_loss: 1917.7778
# Epoch 114/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2084.8036 - val_loss: 1918.2179
# Epoch 115/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2047.5909 - val_loss: 1918.8767
# Epoch 116/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1954.1807 - val_loss: 1918.2162
# Epoch 117/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1933.9933 - val_loss: 1918.0005
# Epoch 118/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1949.0339 - val_loss: 1915.8766
# Epoch 119/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2006.2764 - val_loss: 1914.1165
# Epoch 120/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2014.9110 - val_loss: 1911.4657
# Epoch 121/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1949.3229 - val_loss: 1912.2571
# Epoch 122/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1973.1240 - val_loss: 1912.7434
# Epoch 123/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1917.9643 - val_loss: 1912.3663
# Epoch 124/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1944.8322 - val_loss: 1910.3772
# Epoch 125/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1932.9343 - val_loss: 1907.6335
# Epoch 126/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1960.6550 - val_loss: 1906.8663
# Epoch 127/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2048.1768 - val_loss: 1907.4672
# Epoch 128/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1960.3392 - val_loss: 1908.2843
# Epoch 129/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1978.9687 - val_loss: 1908.7566
# Epoch 130/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 2102.2595 - val_loss: 1906.5082
# Epoch 131/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1938.5386 - val_loss: 1904.4659
# Epoch 132/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1959.0200 - val_loss: 1905.7173
# Epoch 133/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1959.5830 - val_loss: 1904.4930
# Epoch 134/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1927.9361 - val_loss: 1903.6321
# Epoch 135/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2098.0992 - val_loss: 1903.2499
# Epoch 136/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 2055.5676 - val_loss: 1905.4978
# Epoch 137/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1974.3194 - val_loss: 1906.1320
# Epoch 138/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1945.1077 - val_loss: 1904.7418
# Epoch 139/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1954.6332 - val_loss: 1903.7430
# Epoch 140/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1949.2770 - val_loss: 1903.2432
# Epoch 141/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1946.1414 - val_loss: 1902.1315
# Epoch 142/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1946.2836 - val_loss: 1900.4998
# Epoch 143/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1955.3875 - val_loss: 1899.5925
# Epoch 144/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2066.7938 - val_loss: 1899.4913
# Epoch 145/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1940.5423 - val_loss: 1897.1182
# Epoch 146/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1919.8936 - val_loss: 1895.8663
# Epoch 147/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1898.4625 - val_loss: 1893.4719
# Epoch 148/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1952.8146 - val_loss: 1890.4669
# Epoch 149/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1890.7758 - val_loss: 1888.2843
# Epoch 150/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1946.1346 - val_loss: 1887.4929
# Epoch 151/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1911.9055 - val_loss: 1887.8837
# Epoch 152/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1948.3558 - val_loss: 1891.3729
# Epoch 153/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1924.3167 - val_loss: 1891.3822
# Epoch 154/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1908.5745 - val_loss: 1888.5972
# Epoch 155/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2033.9759 - val_loss: 1888.3733
# Epoch 156/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1926.7331 - val_loss: 1888.9995
# Epoch 157/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1994.6284 - val_loss: 1889.0281
# Epoch 158/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1939.8721 - val_loss: 1891.1249
# Epoch 159/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1926.6872 - val_loss: 1890.2764
# Epoch 160/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1905.0782 - val_loss: 1885.3833
# Epoch 161/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1884.2581 - val_loss: 1883.1162
# Epoch 162/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1900.9217 - val_loss: 1881.1594
# Epoch 163/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1923.1291 - val_loss: 1880.7495
# Epoch 164/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1934.4809 - val_loss: 1880.9930
# Epoch 165/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1977.9279 - val_loss: 1880.3418
# Epoch 166/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1995.0700 - val_loss: 1880.2482
# Epoch 167/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1989.2349 - val_loss: 1879.5328
# Epoch 168/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1933.4534 - val_loss: 1878.2828
# Epoch 169/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1922.0368 - val_loss: 1876.5970
# Epoch 170/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1899.4255 - val_loss: 1874.5004
# Epoch 171/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1908.1814 - val_loss: 1872.1228
# Epoch 172/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1918.9484 - val_loss: 1870.6531
# Epoch 173/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1878.1703 - val_loss: 1869.9672
# Epoch 174/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1905.8414 - val_loss: 1869.7169
# Epoch 175/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1930.4405 - val_loss: 1870.0262
# Epoch 176/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1917.1008 - val_loss: 1867.8678
# Epoch 177/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1901.2054 - val_loss: 1867.0017
# Epoch 178/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1956.5383 - val_loss: 1867.6597
# Epoch 179/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 1928.0444 - val_loss: 1864.7566
# Epoch 180/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 1903.5859 - val_loss: 1865.1256
# Epoch 181/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1907.2704 - val_loss: 1865.5083
# Epoch 182/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1894.3177 - val_loss: 1863.9650
# Epoch 183/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1922.1876 - val_loss: 1862.0897
# Epoch 184/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1905.6416 - val_loss: 1862.1268
# Epoch 185/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1911.0723 - val_loss: 1860.5067
# Epoch 186/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1924.4177 - val_loss: 1858.8683
# Epoch 187/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1896.2190 - val_loss: 1858.5072
# Epoch 188/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1872.9560 - val_loss: 1857.7853
# Epoch 189/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1922.0962 - val_loss: 1857.6536
# Epoch 190/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1978.4525 - val_loss: 1858.5913
# Epoch 191/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1931.1954 - val_loss: 1858.5333
# Epoch 192/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1909.0259 - val_loss: 1856.0984
# Epoch 193/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1928.3897 - val_loss: 1854.7771
# Epoch 194/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1959.1731 - val_loss: 1854.2588
# Epoch 195/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1851.9225 - val_loss: 1853.8751
# Epoch 196/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1879.9937 - val_loss: 1854.7521
# Epoch 197/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1935.2330 - val_loss: 1854.7212
# Epoch 198/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1902.4948 - val_loss: 1852.0017
# Epoch 199/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1929.4378 - val_loss: 1851.3479
# Epoch 200/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1878.9123 - val_loss: 1852.1228
# Epoch 201/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1867.6342 - val_loss: 1851.3772
# Epoch 202/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1905.1526 - val_loss: 1850.6268
# Epoch 203/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1920.7962 - val_loss: 1849.8748
# Epoch 204/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1849.8314 - val_loss: 1848.2518
# Epoch 205/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1949.1004 - val_loss: 1847.6230
# Epoch 206/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1868.5581 - val_loss: 1846.9021
# Epoch 207/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1876.7192 - val_loss: 1847.2788
# Epoch 208/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1856.0571 - val_loss: 1846.3683
# Epoch 209/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1860.4453 - val_loss: 1846.3478
# Epoch 210/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1888.5577 - val_loss: 1845.7571
# Epoch 211/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1875.5897 - val_loss: 1845.7145
# Epoch 212/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1881.3126 - val_loss: 1845.1256
# Epoch 213/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1864.0626 - val_loss: 1840.3400
# Epoch 214/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1964.6898 - val_loss: 1840.2855
# Epoch 215/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1831.5167 - val_loss: 1840.3398
# Epoch 216/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1906.0969 - val_loss: 1840.8818
# Epoch 217/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1905.3334 - val_loss: 1839.2505
# Epoch 218/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1875.9183 - val_loss: 1837.5022
# Epoch 219/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1855.6773 - val_loss: 1836.6536
# Epoch 220/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1862.0473 - val_loss: 1835.1268
# Epoch 221/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1846.7965 - val_loss: 1835.2225
# Epoch 222/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1867.8474 - val_loss: 1834.6520
# Epoch 223/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1825.0773 - val_loss: 1834.5975
# Epoch 224/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1802.5392 - val_loss: 1834.5070
# Epoch 225/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1919.8110 - val_loss: 1833.9036
# Epoch 226/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 1819.7195 - val_loss: 1835.9091
# Epoch 227/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 1827.0706 - val_loss: 1835.1603
# Epoch 228/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1879.7703 - val_loss: 1834.0289
# Epoch 229/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1822.8538 - val_loss: 1831.4911
# Epoch 230/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1835.1978 - val_loss: 1830.8463
# Epoch 231/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1862.1998 - val_loss: 1831.9084
# Epoch 232/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1860.0968 - val_loss: 1832.8661
# Epoch 233/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1817.7454 - val_loss: 1830.6267
# Epoch 234/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1883.2097 - val_loss: 1828.9020
# Epoch 235/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1890.8899 - val_loss: 1828.1249
# Epoch 236/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1835.7897 - val_loss: 1827.7589
# Epoch 237/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1965.8488 - val_loss: 1828.9994
# Epoch 238/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1862.2754 - val_loss: 1828.5271
# Epoch 239/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1834.0619 - val_loss: 1826.3820
# Epoch 240/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1798.0832 - val_loss: 1823.8665
# Epoch 241/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1807.6413 - val_loss: 1823.4105
# Epoch 242/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1839.8350 - val_loss: 1821.8728
# Epoch 243/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1811.9685 - val_loss: 1821.3757
# Epoch 244/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1803.5737 - val_loss: 1823.0355
# Epoch 245/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1809.2151 - val_loss: 1824.1542
# Epoch 246/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1833.0893 - val_loss: 1822.6177
# Epoch 247/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1814.8790 - val_loss: 1820.7839
# Epoch 248/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1772.9891 - val_loss: 1820.5957
# Epoch 249/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1849.2505 - val_loss: 1820.2570
# Epoch 250/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 1798.4154 - val_loss: 1820.1177
# Epoch 251/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1797.5382 - val_loss: 1819.8661
# Epoch 252/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1806.3233 - val_loss: 1818.3732
# Epoch 253/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1819.1027 - val_loss: 1817.2585
# Epoch 254/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1802.7689 - val_loss: 1814.9994
# Epoch 255/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1827.6771 - val_loss: 1813.6337
# Epoch 256/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1843.1190 - val_loss: 1815.1273
# Epoch 257/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1768.3774 - val_loss: 1815.3818
# Epoch 258/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1835.1132 - val_loss: 1812.2518
# Epoch 259/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1862.3199 - val_loss: 1811.4980
# Epoch 260/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1861.5632 - val_loss: 1815.0355
# Epoch 261/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1853.2243 - val_loss: 1818.6165
# Epoch 262/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1882.4799 - val_loss: 1815.9092
# Epoch 263/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1833.2092 - val_loss: 1814.7161
# Epoch 264/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1818.9842 - val_loss: 1816.3392
# Epoch 265/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1782.7326 - val_loss: 1815.6268
# Epoch 266/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1846.1385 - val_loss: 1814.5961
# Epoch 267/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1809.2748 - val_loss: 1815.8748
# Epoch 268/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1875.0742 - val_loss: 1818.1268
# Epoch 269/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1842.1002 - val_loss: 1818.3479
#
# Epoch 00269: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 270/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1911.5696 - val_loss: 1818.4640
# Epoch 271/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1759.6684 - val_loss: 1818.3751
# Epoch 272/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1803.2593 - val_loss: 1818.0017
# Epoch 273/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1764.9927 - val_loss: 1817.5007
# Epoch 274/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1798.3998 - val_loss: 1816.8682
# Epoch 275/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1741.5751 - val_loss: 1816.3733
# Epoch 276/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1781.7705 - val_loss: 1816.1340
# Epoch 277/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1746.9069 - val_loss: 1815.8660
# Epoch 278/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1837.3079 - val_loss: 1815.5070
# Epoch 279/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1810.0684 - val_loss: 1815.1337
# Restoring model weights from the end of the best epoch
#
# Epoch 00279: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 00279: early stopping

# %%
plt.plot(CombinedModel.history.history['loss'])
plt.plot(CombinedModel.history.history['val_loss'])
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Mean Model (Constant Loss Function)')
plt.legend(['Train', 'Validation'])
plt.show()
# Out:
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.

# %%
CheckPoint2 = ModelCheckpoint('models_GALAXIA/TrainingErrorBars_{epoch:04d}.hdf5',
                             verbose=0,
                             save_best_only=False
                            )
ES2 = EarlyStopping(patience=20, verbose=True, restore_best_weights=True)
RLR2 = ReduceLROnPlateau(patience=10, min_lr=1e-5)
CSV_logger2 = CSVLogger(filename='logs/training_errorbars.log', separator=',', append=False)

mycallbacks2 = [CheckPoint2, ES2, RLR2, CSV_logger2]
#mycallbacks2 = [ES2, RLR2]

# %%
ConfEst.trainable = True
MeanEst.trainable = False
CombinedModel.compile(loss=LikelihoodLossFunction,
                      optimizer='adam'
                     )

CombinedModel.fit_generator(TrainLoader,
                            validation_data=ValLoader,
                            epochs=1000,
                            callbacks = mycallbacks2
                 )
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 135ms/step - loss: 387797824936345.6250 - val_loss: 112410098663424.0000
# Epoch 2/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 132459781423104.0000 - val_loss: 7543725752320.0000
# Epoch 3/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 56136182084403.2031 - val_loss: 1011132923904.0000
# Epoch 4/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 35262934915481.6016 - val_loss: 234877239296.0000
# Epoch 5/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 21892419262873.6016 - val_loss: 10936732672.0000
# Epoch 6/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 13476600191385.5996 - val_loss: 10936732672.0000
# Epoch 7/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 10905105294950.4004 - val_loss: 12752.3281
# Epoch 8/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 8182260986675.2002 - val_loss: 10734.0928
# Epoch 9/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 9479664517120.0000 - val_loss: 9741.0010
# Epoch 10/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 6243401090457.5996 - val_loss: 9162.6504
# Epoch 11/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 2698586196377.6001 - val_loss: 8802.0898
# Epoch 12/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 2524850036736.0000 - val_loss: 8569.6328
# Epoch 13/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 3606603242900.7373 - val_loss: 8411.8994
# Epoch 14/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 471316915302.4000 - val_loss: 8304.5303
# Epoch 15/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 3085998779596.7998 - val_loss: 8192.1260
# Epoch 16/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 3245203772620.7998 - val_loss: 7909.8677
# Epoch 17/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 2063554928637.6743 - val_loss: 7673.3652
# Epoch 18/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 2250350893465.6001 - val_loss: 7438.5264
# Epoch 19/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 533518954086.4000 - val_loss: 7289.3579
# Epoch 20/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1142490829209.6001 - val_loss: 7187.8892
# Epoch 21/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 420007300352.0000 - val_loss: 7118.5010
# Epoch 22/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 303976978431.7263 - val_loss: 7071.9907
# Epoch 23/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 65971606309.4447 - val_loss: 7041.0371
# Epoch 24/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 154505095987.2000 - val_loss: 7020.1216
# Epoch 25/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 444281544424.7176 - val_loss: 7006.1406
# Epoch 26/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 2245890447300.9189 - val_loss: 6996.6147
# Epoch 27/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 937974931494.4293 - val_loss: 6990.0015
# Epoch 28/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1214756293836.8000 - val_loss: 6985.5293
# Epoch 29/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 2050411416947.2000 - val_loss: 6982.5283
# Epoch 30/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 2882758982208.0000 - val_loss: 6980.5073
# Epoch 31/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 3782040241766.3999 - val_loss: 6979.1152
# Epoch 32/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 150855910796.8000 - val_loss: 6977.9629
# Epoch 33/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 600650140467.2000 - val_loss: 6976.9702
# Epoch 34/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 453036956160.0000 - val_loss: 6976.1411
# Epoch 35/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 129073364556.9116 - val_loss: 6975.6416
# Epoch 36/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 867550931123.2000 - val_loss: 6975.3848
# Epoch 37/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 512013749657.6000 - val_loss: 6975.0303
# Epoch 38/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 496413553107.7528 - val_loss: 6974.8799
# Epoch 39/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 2836936168251.2661 - val_loss: 6974.6147
# Epoch 40/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 108963757004.8000 - val_loss: 6974.9976
# Epoch 41/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 132614850252.8000 - val_loss: 6975.1206
# Epoch 42/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 387323534508.5518 - val_loss: 6975.3501
# Epoch 43/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1654705965738.3999 - val_loss: 6975.1436
# Epoch 44/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 416931940398.4849 - val_loss: 6975.1133
# Epoch 45/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 54769290724.4902 - val_loss: 6975.0005
# Epoch 46/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 121205309849.6000 - val_loss: 6922.4922
# Epoch 47/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 269547810592.0000 - val_loss: 6748.9629
# Epoch 48/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 574914890433.0409 - val_loss: 6617.3789
# Epoch 49/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 399457686034.2020 - val_loss: 6523.9902
# Epoch 50/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 84637918997.8971 - val_loss: 6459.3398
# Epoch 51/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2980484586905.6001 - val_loss: 6415.0327
# Epoch 52/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 161680173363.2000 - val_loss: 6378.6318
# Epoch 53/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 122521975296.0000 - val_loss: 6337.6260
# Epoch 54/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 46270150775.3029 - val_loss: 6251.0103
# Epoch 55/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 31117057395.7948 - val_loss: 6030.9971
# Epoch 56/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 260756292821.2150 - val_loss: 5537.0024
# Epoch 57/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 103466761032.6780 - val_loss: 4930.9575
# Epoch 58/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 80615367790.5721 - val_loss: 4385.2642
# Epoch 59/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 19405217596.0546 - val_loss: 3882.3040
# Epoch 60/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 14017736204.9209 - val_loss: 3457.5188
# Epoch 61/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 35460266360.8351 - val_loss: 3115.6826
# Epoch 62/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 4260.5892 - val_loss: 2840.2446
# Epoch 63/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1517807968.8500 - val_loss: 2616.9231
# Epoch 64/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 70543216642.2357 - val_loss: 2431.5811
# Epoch 65/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 41918838463.5225 - val_loss: 2275.2717
# Epoch 66/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 16691092738.3373 - val_loss: 2144.6353
# Epoch 67/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1146375500.0915 - val_loss: 2033.3831
# Epoch 68/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 59576493294.6508 - val_loss: 1939.1182
# Epoch 69/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 22228480411.5905 - val_loss: 1857.7480
# Epoch 70/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 2434.1579 - val_loss: 1786.7219
# Epoch 71/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 2362.1616 - val_loss: 1722.8463
# Epoch 72/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2275.5286 - val_loss: 1665.2111
# Epoch 73/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 2414.5212 - val_loss: 1612.8770
# Epoch 74/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2184.4439 - val_loss: 1565.1569
# Epoch 75/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2282.3153 - val_loss: 1519.8832
# Epoch 76/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2628.7059 - val_loss: 1477.8665
# Epoch 77/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 30780896146.1946 - val_loss: 1438.8727
# Epoch 78/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 11582606165.6130 - val_loss: 1402.7471
# Epoch 79/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1832005481.8678 - val_loss: 1368.5002
# Epoch 80/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 4072770721.3323 - val_loss: 1335.9994
# Epoch 81/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1038104978.8664 - val_loss: 1305.2380
# Epoch 82/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 571651780523.3444 - val_loss: 1276.3846
# Epoch 83/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1966.3072 - val_loss: 1248.8781
# Epoch 84/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 47224828191.7557 - val_loss: 1222.7531
# Epoch 85/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1776.1268 - val_loss: 1197.3861
# Epoch 86/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1822.3944 - val_loss: 1172.7388
# Epoch 87/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 6874380831.0921 - val_loss: 1148.4437
# Epoch 88/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 11058491333.6058 - val_loss: 1125.2501
# Epoch 89/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 11861.8981 - val_loss: 1103.1138
# Epoch 90/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 114240142.8390 - val_loss: 1081.8759
# Epoch 91/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 92135078.1845 - val_loss: 1061.2509
# Epoch 92/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1577.6281 - val_loss: 1041.6868
# Epoch 93/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 2013.6654 - val_loss: 1022.8004
# Epoch 94/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 59982820.1268 - val_loss: 1004.4507
# Epoch 95/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 997228791.3345 - val_loss: 986.7656
# Epoch 96/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 10923983704.0397 - val_loss: 969.5490
# Epoch 97/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 40190280565.5387 - val_loss: 952.8134
# Epoch 98/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7062063151.4215 - val_loss: 936.8158
# Epoch 99/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1535.2812 - val_loss: 921.2957
# Epoch 100/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1623.6217 - val_loss: 905.9548
# Epoch 101/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 3035780147.0331 - val_loss: 890.8136
# Epoch 102/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1396.7972 - val_loss: 876.4339
# Epoch 103/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 24892871.3954 - val_loss: 862.2503
# Epoch 104/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 4019924737.7147 - val_loss: 848.4411
# Epoch 105/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 90749194901.4984 - val_loss: 835.1727
# Epoch 106/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 8500912172.3231 - val_loss: 822.4335
# Epoch 107/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 15487129161.4588 - val_loss: 809.9362
# Epoch 108/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1381.6433 - val_loss: 798.0166
# Epoch 109/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 9895568834.4841 - val_loss: 781.8553
# Epoch 110/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1608.5880 - val_loss: 766.5835
# Epoch 111/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1383.6912 - val_loss: 753.1033
# Epoch 112/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 91168133273.6704 - val_loss: 740.8574
# Epoch 113/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1841241628.6098 - val_loss: 729.6862
# Epoch 114/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1676.8360 - val_loss: 719.2325
# Epoch 115/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 67691333045.0107 - val_loss: 709.5451
# Epoch 116/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1227.7201 - val_loss: 700.4606
# Epoch 117/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 8394853462.1412 - val_loss: 691.6442
# Epoch 118/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1482.9290 - val_loss: 683.1874
# Epoch 119/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 717572681.7114 - val_loss: 674.9803
# Epoch 120/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 15308479272.5110 - val_loss: 667.0184
# Epoch 121/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 100699857.6721 - val_loss: 659.1887
# Epoch 122/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 29819074253.1622 - val_loss: 651.5236
# Epoch 123/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1229.8026 - val_loss: 643.9937
# Epoch 124/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1297.7200 - val_loss: 636.5882
# Epoch 125/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 7935146718.2416 - val_loss: 629.3112
# Epoch 126/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1456.7518 - val_loss: 622.1513
# Epoch 127/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 80728008442.5943 - val_loss: 615.0689
# Epoch 128/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1429.4852 - val_loss: 608.2856
# Epoch 129/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 538819692.6008 - val_loss: 601.7231
# Epoch 130/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 26712878379.4616 - val_loss: 595.2133
# Epoch 131/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1422.0299 - val_loss: 588.8138
# Epoch 132/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1262.0186 - val_loss: 582.5837
# Epoch 133/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1182.6184 - val_loss: 576.4588
# Epoch 134/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 584569003325.1631 - val_loss: 570.5643
# Epoch 135/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 95963493381.6665 - val_loss: 564.7151
# Epoch 136/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 1309347873.4235 - val_loss: 558.9609
# Epoch 137/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1659.0753 - val_loss: 553.2274
# Epoch 138/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 13516923855.3134 - val_loss: 547.6893
# Epoch 139/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1432.8891 - val_loss: 542.2269
# Epoch 140/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 2657086401184.3398 - val_loss: 536.8517
# Epoch 141/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 42066295449.5441 - val_loss: 531.5687
# Epoch 142/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1134.3004 - val_loss: 526.5377
# Epoch 143/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 11971774784.6123 - val_loss: 521.6543
# Epoch 144/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 49863775879.0402 - val_loss: 516.8433
# Epoch 145/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 213896950892.1639 - val_loss: 512.0953
# Epoch 146/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 34537674717.9397 - val_loss: 507.3688
# Epoch 147/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 25145845304.7289 - val_loss: 502.6015
# Epoch 148/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1204.5177 - val_loss: 497.9769
# Epoch 149/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1222.4521 - val_loss: 493.4684
# Epoch 150/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2672736865.2748 - val_loss: 489.0704
# Epoch 151/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 4378784117.0397 - val_loss: 484.8443
# Epoch 152/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 4617724739.6623 - val_loss: 480.6019
# Epoch 153/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 11570429.0848 - val_loss: 476.4444
# Epoch 154/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 150553909132.0146 - val_loss: 472.3416
# Epoch 155/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 997.2826 - val_loss: 468.2807
# Epoch 156/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 6243722738.4459 - val_loss: 464.2808
# Epoch 157/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1189.3576 - val_loss: 460.3521
# Epoch 158/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 55980961968.8512 - val_loss: 456.5241
# Epoch 159/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 10455886452.5005 - val_loss: 452.8416
# Epoch 160/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 3762993555.4047 - val_loss: 449.1653
# Epoch 161/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 5835963534.8567 - val_loss: 445.5643
# Epoch 162/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1406.8067 - val_loss: 441.9044
# Epoch 163/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1171.9178 - val_loss: 438.3130
# Epoch 164/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 43546762062.6189 - val_loss: 434.8035
# Epoch 165/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1037.7045 - val_loss: 431.3432
# Epoch 166/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 923399996376.0729 - val_loss: 427.8673
# Epoch 167/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1396.5777 - val_loss: 424.4393
# Epoch 168/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1138.1632 - val_loss: 421.0311
# Epoch 169/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1042.5478 - val_loss: 417.7420
# Epoch 170/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1129.7644 - val_loss: 414.5392
# Epoch 171/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 31852306.7391 - val_loss: 411.3519
# Epoch 172/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 26525389266.3855 - val_loss: 408.1794
# Epoch 173/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 6308696545.5064 - val_loss: 405.0650
# Epoch 174/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 2143794384808.5718 - val_loss: 402.0932
# Epoch 175/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 969.3290 - val_loss: 399.1348
# Epoch 176/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1052.9944 - val_loss: 396.2105
# Epoch 177/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 40438374088.1713 - val_loss: 393.3204
# Epoch 178/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1427.7391 - val_loss: 390.5319
# Epoch 179/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 327534352.0036 - val_loss: 387.7726
# Epoch 180/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2201.4669 - val_loss: 384.9042
# Epoch 181/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 5994.0752 - val_loss: 382.1476
# Epoch 182/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1254.6741 - val_loss: 379.4600
# Epoch 183/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1242.0513 - val_loss: 376.8098
# Epoch 184/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1121.6884 - val_loss: 374.1964
# Epoch 185/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1101.3140 - val_loss: 371.6453
# Epoch 186/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1098.5939 - val_loss: 369.0966
# Epoch 187/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 22546379848.7848 - val_loss: 366.5936
# Epoch 188/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1029.4223 - val_loss: 364.0847
# Epoch 189/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 919.7707 - val_loss: 361.6278
# Epoch 190/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1030.3864 - val_loss: 359.1989
# Epoch 191/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 52116579196.6788 - val_loss: 356.8124
# Epoch 192/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 12853.5801 - val_loss: 354.3772
# Epoch 193/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 14780328634.5670 - val_loss: 351.7820
# Epoch 194/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1273.4320 - val_loss: 349.3218
# Epoch 195/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 214498849.6953 - val_loss: 346.5425
# Epoch 196/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 917.1410 - val_loss: 343.6652
# Epoch 197/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 17867109122.6073 - val_loss: 341.0120
# Epoch 198/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 17584589315.7408 - val_loss: 338.5631
# Epoch 199/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 3389168538.5878 - val_loss: 336.2620
# Epoch 200/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 770254963.6750 - val_loss: 334.1030
# Epoch 201/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 990.5783 - val_loss: 332.0008
# Epoch 202/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1098.6545 - val_loss: 329.9063
# Epoch 203/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1069.5447 - val_loss: 327.8313
# Epoch 204/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1066117483.3562 - val_loss: 325.7499
# Epoch 205/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1145.4598 - val_loss: 323.7397
# Epoch 206/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 675834513.2697 - val_loss: 321.7910
# Epoch 207/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1299.6447 - val_loss: 319.8654
# Epoch 208/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1113462102.5220 - val_loss: 317.9718
# Epoch 209/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 3192366005.2164 - val_loss: 316.1242
# Epoch 210/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1064.0786 - val_loss: 314.3229
# Epoch 211/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 5144.1423 - val_loss: 312.5593
# Epoch 212/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 157255204.1859 - val_loss: 310.7845
# Epoch 213/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 18120498926.9370 - val_loss: 308.9793
# Epoch 214/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 17373819584.1802 - val_loss: 307.0525
# Epoch 215/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 3077.7739 - val_loss: 296.9582
# Epoch 216/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 17516322620.2520 - val_loss: 283.9029
# Epoch 217/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 20707675322.0452 - val_loss: 275.3785
# Epoch 218/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 966.3296 - val_loss: 269.6400
# Epoch 219/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 5189.5301 - val_loss: 265.6416
# Epoch 220/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 1486.9902 - val_loss: 262.7375
# Epoch 221/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 74437171982.9316 - val_loss: 260.5459
# Epoch 222/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 859.7714 - val_loss: 258.8087
# Epoch 223/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 855.7967 - val_loss: 257.3718
# Epoch 224/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 17543413522.3830 - val_loss: 256.1414
# Epoch 225/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 974.1097 - val_loss: 255.0587
# Epoch 226/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 48298750311.1942 - val_loss: 254.0499
# Epoch 227/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 915.1529 - val_loss: 253.1055
# Epoch 228/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 906.1371 - val_loss: 252.1875
# Epoch 229/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 11181803238.9766 - val_loss: 251.3092
# Epoch 230/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1166.3453 - val_loss: 250.4493
# Epoch 231/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1003.4143 - val_loss: 249.6094
# Epoch 232/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 49705374025.3786 - val_loss: 248.7938
# Epoch 233/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 9860206164.4429 - val_loss: 247.9997
# Epoch 234/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 892.1017 - val_loss: 247.1916
# Epoch 235/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 100051346283.2105 - val_loss: 246.3867
# Epoch 236/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 943.0102 - val_loss: 245.5771
# Epoch 237/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1304.0565 - val_loss: 244.7778
# Epoch 238/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 8067281.4323 - val_loss: 243.9841
# Epoch 239/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 8488025979.1271 - val_loss: 243.1915
# Epoch 240/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 628877971.9298 - val_loss: 242.4070
# Epoch 241/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1283.8491 - val_loss: 241.6284
# Epoch 242/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 8288727761.3581 - val_loss: 240.8585
# Epoch 243/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 7091469886.6839 - val_loss: 240.0823
# Epoch 244/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 24247345410.5451 - val_loss: 239.3125
# Epoch 245/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1725.9162 - val_loss: 238.5428
# Epoch 246/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1657064178075.5969 - val_loss: 237.7802
# Epoch 247/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 5314.5269 - val_loss: 237.0156
# Epoch 248/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 988.4478 - val_loss: 236.2615
# Epoch 249/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1668.0609 - val_loss: 235.5189
# Epoch 250/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 604246230.0065 - val_loss: 234.7812
# Epoch 251/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1034357098.0952 - val_loss: 234.0321
# Epoch 252/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 892.7094 - val_loss: 233.2802
# Epoch 253/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 962.7779 - val_loss: 232.5190
# Epoch 254/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1177.8786 - val_loss: 231.7846
# Epoch 255/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1027.1756 - val_loss: 231.0478
# Epoch 256/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1069.0321 - val_loss: 230.3114
# Epoch 257/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 68456436624.1319 - val_loss: 229.5772
# Epoch 258/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1041.1556 - val_loss: 228.8440
# Epoch 259/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 916.4952 - val_loss: 228.1293
# Epoch 260/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1407.3692 - val_loss: 227.4330
# Epoch 261/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 16988623976.6310 - val_loss: 226.7378
# Epoch 262/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 37617103161.6306 - val_loss: 226.0467
# Epoch 263/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 4163296619.6630 - val_loss: 225.3557
# Epoch 264/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 72918339918.5077 - val_loss: 224.6597
# Epoch 265/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 6130752433.9749 - val_loss: 223.9699
# Epoch 266/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1028.2132 - val_loss: 223.2925
# Epoch 267/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 880.6463 - val_loss: 222.6084
# Epoch 268/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 7749714400.8773 - val_loss: 221.9265
# Epoch 269/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 8710964032.8876 - val_loss: 221.2544
# Epoch 270/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 24693398646.3364 - val_loss: 218.8713
# Epoch 271/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 906.3690 - val_loss: 217.0937
# Epoch 272/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 1141.4809 - val_loss: 215.7308
# Epoch 273/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 920.7914 - val_loss: 214.6103
# Epoch 274/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 185673432847.7100 - val_loss: 213.6716
# Epoch 275/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1831.6452 - val_loss: 212.8476
# Epoch 276/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 972.2451 - val_loss: 212.1055
# Epoch 277/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 936.9047 - val_loss: 211.3954
# Epoch 278/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 852.4046 - val_loss: 210.7341
# Epoch 279/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 85968143.2876 - val_loss: 210.0926
# Epoch 280/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 924.4337 - val_loss: 209.4543
# Epoch 281/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 910.6804 - val_loss: 208.8320
# Epoch 282/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 877.5298 - val_loss: 208.2071
# Epoch 283/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1468.6475 - val_loss: 207.5937
# Epoch 284/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 849.1233 - val_loss: 206.9841
# Epoch 285/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 812.1776 - val_loss: 206.3760
# Epoch 286/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1017.5070 - val_loss: 205.7696
# Epoch 287/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 668608479.6239 - val_loss: 205.1719
# Epoch 288/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 973.8591 - val_loss: 204.5665
# Epoch 289/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 91976747973.7855 - val_loss: 203.9728
# Epoch 290/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1373.3858 - val_loss: 203.3909
# Epoch 291/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 10002678002.2969 - val_loss: 202.8234
# Epoch 292/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 810.0440 - val_loss: 202.2501
# Epoch 293/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 945.6568 - val_loss: 201.6718
# Epoch 294/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 884.1862 - val_loss: 201.1043
# Epoch 295/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 964.7215 - val_loss: 200.5322
# Epoch 296/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 10378060124.0959 - val_loss: 199.9685
# Epoch 297/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 967.8959 - val_loss: 199.4024
# Epoch 298/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 875.2729 - val_loss: 198.8440
# Epoch 299/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 14282126379.3874 - val_loss: 198.2852
# Epoch 300/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 1645794803.7183 - val_loss: 197.7451
# Epoch 301/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 823.8256 - val_loss: 197.2136
# Epoch 302/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 5213282636.4389 - val_loss: 196.6719
# Epoch 303/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 776.9780 - val_loss: 196.1253
# Epoch 304/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 2177.7226 - val_loss: 195.5417
# Epoch 305/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 6693049.2643 - val_loss: 194.9534
# Epoch 306/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 919.4444 - val_loss: 194.3790
# Epoch 307/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 1274.1686 - val_loss: 193.8082
# Epoch 308/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 715.2149 - val_loss: 193.2550
# Epoch 309/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1895584275.5138 - val_loss: 192.7084
# Epoch 310/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 919.1957 - val_loss: 192.1719
# Epoch 311/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1082.0467 - val_loss: 191.6366
# Epoch 312/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 10405157449.4484 - val_loss: 191.1095
# Epoch 313/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 859.6990 - val_loss: 190.5832
# Epoch 314/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 8819382902.1055 - val_loss: 190.0472
# Epoch 315/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1180.9981 - val_loss: 189.5113
# Epoch 316/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 1229.3337 - val_loss: 188.9857
# Epoch 317/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 748.4393 - val_loss: 188.4729
# Epoch 318/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 903.2857 - val_loss: 187.9518
# Epoch 319/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1286.4003 - val_loss: 187.4321
# Epoch 320/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 878.5807 - val_loss: 186.9219
# Epoch 321/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 745.3347 - val_loss: 186.4209
# Epoch 322/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 765.0871 - val_loss: 185.9117
# Epoch 323/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 3751.3651 - val_loss: 185.4074
# Epoch 324/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 863.3142 - val_loss: 184.9164
# Epoch 325/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 895.9286 - val_loss: 184.4220
# Epoch 326/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 949.4823 - val_loss: 183.9322
# Epoch 327/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 849.0921 - val_loss: 183.4263
# Epoch 328/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 862.6886 - val_loss: 182.9263
# Epoch 329/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 12500412310.0611 - val_loss: 182.4272
# Epoch 330/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1048.8161 - val_loss: 181.9321
# Epoch 331/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7291696775.4980 - val_loss: 181.4272
# Epoch 332/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1057.1253 - val_loss: 180.9262
# Epoch 333/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 786.7531 - val_loss: 180.4208
# Epoch 334/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1000.5978 - val_loss: 179.9232
# Epoch 335/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 853.6773 - val_loss: 179.4478
# Epoch 336/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 5333448691.3128 - val_loss: 178.9787
# Epoch 337/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 862.0970 - val_loss: 178.5054
# Epoch 338/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 40130444270.2955 - val_loss: 178.0422
# Epoch 339/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 37075202903.3850 - val_loss: 177.5737
# Epoch 340/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 960.2345 - val_loss: 177.1050
# Epoch 341/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 35523581718.6360 - val_loss: 176.6505
# Epoch 342/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1018.0114 - val_loss: 176.1919
# Epoch 343/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 2410.6995 - val_loss: 175.7333
# Epoch 344/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 779.6841 - val_loss: 175.2609
# Epoch 345/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 41860100454.6184 - val_loss: 174.7924
# Epoch 346/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 991.8597 - val_loss: 174.3284
# Epoch 347/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 867.7861 - val_loss: 173.8595
# Epoch 348/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 830.8827 - val_loss: 173.3904
# Epoch 349/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 40867049520.1488 - val_loss: 172.9263
# Epoch 350/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1092.7959 - val_loss: 172.4591
# Epoch 351/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 864.0634 - val_loss: 171.9989
# Epoch 352/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 9061091574.3065 - val_loss: 171.5455
# Epoch 353/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 733.9474 - val_loss: 171.0922
# Epoch 354/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 6252239.3435 - val_loss: 170.6404
# Epoch 355/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1802409794.7455 - val_loss: 170.1986
# Epoch 356/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 799.4031 - val_loss: 169.7597
# Epoch 357/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 951.9965 - val_loss: 169.3182
# Epoch 358/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 955.8055 - val_loss: 168.8846
# Epoch 359/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 3395254487.8466 - val_loss: 168.4528
# Epoch 360/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 901.2056 - val_loss: 168.0252
# Epoch 361/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 821.2752 - val_loss: 167.6036
# Epoch 362/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 851.7862 - val_loss: 167.1768
# Epoch 363/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 887.9951 - val_loss: 166.7450
# Epoch 364/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 19440102594.0052 - val_loss: 166.3140
# Epoch 365/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 896.8745 - val_loss: 165.8953
# Epoch 366/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1113.8447 - val_loss: 165.4700
# Epoch 367/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 852.1433 - val_loss: 165.0470
# Epoch 368/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 919.3235 - val_loss: 164.6300
# Epoch 369/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 752.8960 - val_loss: 164.2128
# Epoch 370/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 6573787232.5948 - val_loss: 163.7909
# Epoch 371/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1007.6856 - val_loss: 163.3656
# Epoch 372/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 870.5704 - val_loss: 162.9390
# Epoch 373/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 3536.0547 - val_loss: 162.5204
# Epoch 374/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 680.3473 - val_loss: 162.1046
# Epoch 375/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 2020630207407.5469 - val_loss: 161.6935
# Epoch 376/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1197.9985 - val_loss: 161.2825
# Epoch 377/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 144942873.1568 - val_loss: 160.8766
# Epoch 378/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 958.9015 - val_loss: 160.4739
# Epoch 379/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 26042786531.0947 - val_loss: 160.0721
# Epoch 380/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 781773197.4131 - val_loss: 159.6718
# Epoch 381/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 784.0258 - val_loss: 159.2752
# Epoch 382/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 824.6031 - val_loss: 158.8846
# Epoch 383/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1602.5990 - val_loss: 158.4951
# Epoch 384/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 775.4023 - val_loss: 158.1098
# Epoch 385/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 897.8824 - val_loss: 157.7279
# Epoch 386/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 4871042631.5549 - val_loss: 157.3424
# Epoch 387/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1028.3120 - val_loss: 156.9531
# Epoch 388/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1033.7361 - val_loss: 156.5674
# Epoch 389/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 100595618157.3543 - val_loss: 156.1888
# Epoch 390/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 960.1816 - val_loss: 155.8109
# Epoch 391/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 923.6680 - val_loss: 155.4169
# Epoch 392/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 5955144198.5354 - val_loss: 155.0317
# Epoch 393/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 17466798828.7519 - val_loss: 154.6509
# Epoch 394/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 855.4991 - val_loss: 154.2796
# Epoch 395/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 124854876875.3039 - val_loss: 153.8999
# Epoch 396/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 905.7227 - val_loss: 153.5219
# Epoch 397/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 960.6571 - val_loss: 153.1460
# Epoch 398/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 663894625.0213 - val_loss: 152.7719
# Epoch 399/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 886.3079 - val_loss: 152.3996
# Epoch 400/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1102.9436 - val_loss: 152.0309
# Epoch 401/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 793.7788 - val_loss: 151.6617
# Epoch 402/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 4996.1773 - val_loss: 151.2902
# Epoch 403/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 53791172774.0068 - val_loss: 150.9168
# Epoch 404/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 983.9715 - val_loss: 150.5482
# Epoch 405/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 18113725156.3308 - val_loss: 150.1862
# Epoch 406/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 33452743637.2649 - val_loss: 149.8193
# Epoch 407/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 18432025273.5787 - val_loss: 149.4544
# Epoch 408/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 905.7506 - val_loss: 149.0882
# Epoch 409/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 919.9222 - val_loss: 148.7201
# Epoch 410/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 836.0581 - val_loss: 148.3595
# Epoch 411/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 878.6291 - val_loss: 148.0056
# Epoch 412/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 873.5560 - val_loss: 147.6509
# Epoch 413/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1220025537.7493 - val_loss: 147.2913
# Epoch 414/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 46628721239.3700 - val_loss: 146.9361
# Epoch 415/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 871.5041 - val_loss: 146.5850
# Epoch 416/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 759.2738 - val_loss: 146.2344
# Epoch 417/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 674.6870 - val_loss: 145.8910
# Epoch 418/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 833.1484 - val_loss: 145.5485
# Epoch 419/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 941.8848 - val_loss: 145.2085
# Epoch 420/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 24985035.0311 - val_loss: 144.8696
# Epoch 421/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 856.5654 - val_loss: 144.5370
# Epoch 422/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 10868607157.5806 - val_loss: 144.2031
# Epoch 423/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 816.2125 - val_loss: 143.8682
# Epoch 424/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 885.1886 - val_loss: 143.5326
# Epoch 425/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 770.3122 - val_loss: 143.2030
# Epoch 426/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 2221.9178 - val_loss: 142.8736
# Epoch 427/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 753.5387 - val_loss: 142.5464
# Epoch 428/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 926.8672 - val_loss: 142.2192
# Epoch 429/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 867.2511 - val_loss: 141.8961
# Epoch 430/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 936.2251 - val_loss: 141.5679
# Epoch 431/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1183.5581 - val_loss: 141.2415
# Epoch 432/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 949.4939 - val_loss: 140.9147
# Epoch 433/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 784.7551 - val_loss: 140.5882
# Epoch 434/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 22783841329.4441 - val_loss: 140.2656
# Epoch 435/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1021.4242 - val_loss: 139.9462
# Epoch 436/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 7136696211.2877 - val_loss: 139.6255
# Epoch 437/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 855.1888 - val_loss: 139.3129
# Epoch 438/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 713.1631 - val_loss: 138.9917
# Epoch 439/1000
# ...
# 4/4 [==============================] - 0s 35ms/step - loss: 692.6322 - val_loss: 62.9367
# Epoch 851/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 748.8333 - val_loss: 62.8359
# Epoch 852/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1044645648.7278 - val_loss: 62.7344
# Epoch 853/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 927.9201 - val_loss: 62.6357
# Epoch 854/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 14039.9475 - val_loss: 62.5343
# Epoch 855/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 817.3012 - val_loss: 62.4297
# Epoch 856/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 171193619748.0595 - val_loss: 62.3281
# Epoch 857/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 764.2849 - val_loss: 62.2273
# Epoch 858/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 795.1045 - val_loss: 62.1292
# Epoch 859/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 673.5981 - val_loss: 62.0321
# Epoch 860/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 633.3846 - val_loss: 61.9375
# Epoch 861/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 75770823863.5057 - val_loss: 61.8391
# Epoch 862/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 2968.8380 - val_loss: 61.7385
# Epoch 863/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 594.6984 - val_loss: 61.6375
# Epoch 864/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1039.5952 - val_loss: 61.5391
# Epoch 865/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 841.5558 - val_loss: 61.4383
# Epoch 866/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 356536708.2155 - val_loss: 61.3430
# Epoch 867/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 672.6686 - val_loss: 61.2469
# Epoch 868/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 652.9244 - val_loss: 61.1521
# Epoch 869/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 19774044581.1598 - val_loss: 61.0555
# Epoch 870/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 726.5897 - val_loss: 60.9648
# Epoch 871/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 751.5662 - val_loss: 60.8721
# Epoch 872/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 2305408333.5957 - val_loss: 60.7810
# Epoch 873/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 48240172818.0851 - val_loss: 60.6883
# Epoch 874/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 880.9301 - val_loss: 60.5975
# Epoch 875/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1802.7036 - val_loss: 60.5048
# Epoch 876/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 787.0528 - val_loss: 60.4141
# Epoch 877/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 719.1676 - val_loss: 60.3244
# Epoch 878/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 773.7461 - val_loss: 60.2344
# Epoch 879/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 764.7094 - val_loss: 60.1445
# Epoch 880/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1403225849.9546 - val_loss: 60.0578
# Epoch 881/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 943.5639 - val_loss: 59.9688
# Epoch 882/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 808.2699 - val_loss: 59.8817
# Epoch 883/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 400543943.1721 - val_loss: 59.7893
# Epoch 884/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 797.9821 - val_loss: 59.6990
# Epoch 885/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 830.8118 - val_loss: 59.6094
# Epoch 886/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 207251251772.3621 - val_loss: 59.5204
# Epoch 887/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 821.8017 - val_loss: 59.4338
# Epoch 888/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 777.5379 - val_loss: 59.3438
# Epoch 889/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 909.2533 - val_loss: 59.2547
# Epoch 890/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 709.0337 - val_loss: 59.1671
# Epoch 891/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 753.3161 - val_loss: 59.0789
# Epoch 892/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 723.8863 - val_loss: 58.9921
# Epoch 893/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1045.0920 - val_loss: 58.9026
# Epoch 894/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 740.4854 - val_loss: 58.8156
# Epoch 895/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1526664794.5226 - val_loss: 58.7268
# Epoch 896/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 678.0918 - val_loss: 58.6378
# Epoch 897/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 5492845.2791 - val_loss: 58.5480
# Epoch 898/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1787409654.9759 - val_loss: 58.4609
# Epoch 899/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 8473885183.4118 - val_loss: 58.3714
# Epoch 900/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 748.4938 - val_loss: 58.2849
# Epoch 901/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 2492.0687 - val_loss: 58.1945
# Epoch 902/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 646.0377 - val_loss: 58.1015
# Epoch 903/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 723.0915 - val_loss: 58.0109
# Epoch 904/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 663.9720 - val_loss: 57.9219
# Epoch 905/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 804.2057 - val_loss: 57.8331
# Epoch 906/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 896.5996 - val_loss: 57.7461
# Epoch 907/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 746.3686 - val_loss: 57.6602
# Epoch 908/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1637621959.9888 - val_loss: 57.5742
# Epoch 909/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 625.3894 - val_loss: 57.4886
# Epoch 910/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1592.8656 - val_loss: 57.4034
# Epoch 911/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 914.5636 - val_loss: 57.3167
# Epoch 912/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 378844233.7183 - val_loss: 57.2305
# Epoch 913/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 629.2338 - val_loss: 57.1456
# Epoch 914/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 587.2539 - val_loss: 57.0597
# Epoch 915/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 685.7614 - val_loss: 56.9766
# Epoch 916/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1814.2289 - val_loss: 56.8946
# Epoch 917/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 747.4108 - val_loss: 56.8126
# Epoch 918/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 839.7903 - val_loss: 56.7307
# Epoch 919/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 692.5480 - val_loss: 56.6494
# Epoch 920/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 739.6181 - val_loss: 56.5667
# Epoch 921/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 702.8179 - val_loss: 56.4844
# Epoch 922/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 622.3320 - val_loss: 56.4024
# Epoch 923/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 754884882.1287 - val_loss: 56.3194
# Epoch 924/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 302967740294.2784 - val_loss: 56.2372
# Epoch 925/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 871.3578 - val_loss: 56.1535
# Epoch 926/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 15687803858.8626 - val_loss: 56.0704
# Epoch 927/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 950.0253 - val_loss: 55.9855
# Epoch 928/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 713.8906 - val_loss: 55.9015
# Epoch 929/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 7114476450.1212 - val_loss: 55.8167
# Epoch 930/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 14939587988.0200 - val_loss: 55.7344
# Epoch 931/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 649.8782 - val_loss: 55.6526
# Epoch 932/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 614.5528 - val_loss: 55.5712
# Epoch 933/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 26031848423.3039 - val_loss: 55.4892
# Epoch 934/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 632.9051 - val_loss: 55.4073
# Epoch 935/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 159964267.8272 - val_loss: 55.3272
# Epoch 936/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 828.8316 - val_loss: 55.2458
# Epoch 937/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 729.4042 - val_loss: 55.1643
# Epoch 938/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 691.7580 - val_loss: 55.0848
# Epoch 939/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 11664982935.5550 - val_loss: 55.0042
# Epoch 940/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 910.3156 - val_loss: 54.9259
# Epoch 941/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 671.6784 - val_loss: 54.8448
# Epoch 942/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 776.1018 - val_loss: 54.7653
# Epoch 943/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 757.5312 - val_loss: 54.6848
# Epoch 944/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 703.1034 - val_loss: 54.6064
# Epoch 945/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 29435242.5777 - val_loss: 54.5284
# Epoch 946/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 3006802695.2223 - val_loss: 54.4522
# Epoch 947/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 601.7163 - val_loss: 54.3738
# Epoch 948/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 785.0695 - val_loss: 54.2930
# Epoch 949/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 202479221840.6387 - val_loss: 54.2149
# Epoch 950/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 876.3167 - val_loss: 54.1368
# Epoch 951/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 569.8520 - val_loss: 54.0586
# Epoch 952/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 717.2055 - val_loss: 53.9775
# Epoch 953/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 993.0555 - val_loss: 53.8984
# Epoch 954/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 738.4956 - val_loss: 53.8203
# Epoch 955/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 673.6057 - val_loss: 53.7419
# Epoch 956/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 702.5145 - val_loss: 53.6629
# Epoch 957/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 697.5124 - val_loss: 53.5811
# Epoch 958/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 802.4272 - val_loss: 53.4961
# Epoch 959/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 3130261976.7622 - val_loss: 53.4140
# Epoch 960/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 699.6689 - val_loss: 53.3332
# Epoch 961/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 5889846051.2786 - val_loss: 53.2541
# Epoch 962/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 846.2061 - val_loss: 53.1755
# Epoch 963/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 6209922489.3148 - val_loss: 53.0974
# Epoch 964/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 688.6153 - val_loss: 53.0196
# Epoch 965/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 761.2814 - val_loss: 52.9426
# Epoch 966/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 655.0904 - val_loss: 52.8672
# Epoch 967/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 625.2707 - val_loss: 52.7900
# Epoch 968/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 601.6933 - val_loss: 52.7136
# Epoch 969/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 19535029715.0526 - val_loss: 52.6364
# Epoch 970/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 721.0700 - val_loss: 52.5598
# Epoch 971/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 710.5323 - val_loss: 52.4853
# Epoch 972/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 725.6339 - val_loss: 52.4102
# Epoch 973/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 256866605052.7910 - val_loss: 52.3350
# Epoch 974/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 533377444022.1017 - val_loss: 52.2606
# Epoch 975/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 587762317.3147 - val_loss: 52.1863
# Epoch 976/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 628.9462 - val_loss: 52.1121
# Epoch 977/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 772.5387 - val_loss: 52.0391
# Epoch 978/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 3962548435.7239 - val_loss: 51.9678
# Epoch 979/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 920.8595 - val_loss: 51.8945
# Epoch 980/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 653.6998 - val_loss: 51.8206
# Epoch 981/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 886.0863 - val_loss: 51.7459
# Epoch 982/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 765.1484 - val_loss: 51.6692
# Epoch 983/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 656.7774 - val_loss: 51.5938
# Epoch 984/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 765.7267 - val_loss: 51.5193
# Epoch 985/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 602.5875 - val_loss: 51.4444
# Epoch 986/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 12137.1732 - val_loss: 51.3699
# Epoch 987/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 110764656039.1920 - val_loss: 51.2959
# Epoch 988/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 6826562759.6959 - val_loss: 51.2224
# Epoch 989/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 674.7687 - val_loss: 51.1474
# Epoch 990/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 718.1930 - val_loss: 51.0732
# Epoch 991/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 659.5717 - val_loss: 50.9970
# Epoch 992/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 1897511309.7991 - val_loss: 50.9219
# Epoch 993/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 2442.8327 - val_loss: 50.8477
# Epoch 994/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 729.1514 - val_loss: 50.7744
# Epoch 995/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 7566170088.5955 - val_loss: 50.7029
# Epoch 996/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 899.0486 - val_loss: 50.6289
# Epoch 997/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 656.4162 - val_loss: 50.5574
# Epoch 998/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1652.4754 - val_loss: 50.4846
# Epoch 999/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 626.6376 - val_loss: 50.4128
# Epoch 1000/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 663.6675 - val_loss: 50.3399

# %%
plt.plot(CombinedModel.history.history['loss'])
plt.plot(CombinedModel.history.history['val_loss'])
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Confidence Model (Likelihood Loss Function)')
plt.legend(['Train', 'Validation'])
plt.show()

# %% [markdown]
# ## Second Training Iteration

# %%
CheckPoint4 = ModelCheckpoint('models_GALAXIA/TrainingMean2_{epoch:04d}.hdf5',
                             verbose=0,
                             save_best_only=False
                            )
ES4 = EarlyStopping(patience=20, verbose=True, restore_best_weights=True)
RLR4 = ReduceLROnPlateau(patience=10, min_lr=1e-5, verbose=True)
CSV_logger4 = CSVLogger(filename='logs/training_mean2.log', separator=',', append=False)

mycallbacks4 = [CheckPoint4, ES4, RLR4, CSV_logger4]
#mycallbacks4 = [ES4, RLR4]

# %%
ConfEst.trainable = False
MeanEst.trainable = True
CombinedModel.compile(loss=ConstantLikelihoodLossFunction,
                      optimizer='adam'
                     )
CombinedModel.fit_generator(TrainLoader,
                            validation_data=ValLoader,
                            epochs=1000,
                            callbacks = mycallbacks4
                 )
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 131ms/step - loss: 1788.8671 - val_loss: 1816.3478
# Epoch 2/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 1840.6337 - val_loss: 1815.0975
# Epoch 3/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1811.3236 - val_loss: 1813.6318
# Epoch 4/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1785.8075 - val_loss: 1810.9658
# Epoch 5/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1780.0779 - val_loss: 1808.1232
# Epoch 6/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1805.1266 - val_loss: 1806.9642
# Epoch 7/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1844.7363 - val_loss: 1807.5071
# Epoch 8/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1787.3691 - val_loss: 1808.1323
# Epoch 9/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1763.8783 - val_loss: 1810.4094
# Epoch 10/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1846.1519 - val_loss: 1808.2520
# Epoch 11/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1774.0117 - val_loss: 1803.7429
# Epoch 12/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1806.9718 - val_loss: 1801.0022
# Epoch 13/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1801.3100 - val_loss: 1799.9097
# Epoch 14/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1776.1193 - val_loss: 1800.2571
# Epoch 15/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1782.5100 - val_loss: 1800.1180
# Epoch 16/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1832.9889 - val_loss: 1801.4653
# Epoch 17/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1807.7742 - val_loss: 1802.3408
# Epoch 18/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1754.0659 - val_loss: 1802.7410
# Epoch 19/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1829.9852 - val_loss: 1802.9908
# Epoch 20/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1800.8661 - val_loss: 1803.6545
# Epoch 21/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1772.0206 - val_loss: 1803.2141
# Epoch 22/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1811.7894 - val_loss: 1801.6324
# Epoch 23/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1807.6222 - val_loss: 1799.9913
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 24/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1836.2637 - val_loss: 1799.9039
# Epoch 25/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1826.9498 - val_loss: 1799.7573
# Epoch 26/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1754.3315 - val_loss: 1799.6251
# Epoch 27/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1762.1875 - val_loss: 1799.5887
# Epoch 28/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1821.7997 - val_loss: 1799.6525
# Epoch 29/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1868.6367 - val_loss: 1799.7413
# Epoch 30/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1802.1895 - val_loss: 1799.7792
# Epoch 31/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1784.1028 - val_loss: 1799.7426
# Epoch 32/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1772.8782 - val_loss: 1799.5956
# Epoch 33/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 1795.7515 - val_loss: 1799.5360
# Epoch 34/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 1796.3948 - val_loss: 1799.5975
# Epoch 35/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 1782.1851 - val_loss: 1799.6267
# Epoch 36/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1737.2298 - val_loss: 1799.7482
# Epoch 37/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1780.7551 - val_loss: 1800.0017
# Epoch 38/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1852.2294 - val_loss: 1800.1233
# Epoch 39/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1920.8358 - val_loss: 1800.0364
# Epoch 40/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1855.4798 - val_loss: 1800.1158
# Epoch 41/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1787.2127 - val_loss: 1800.0342
# Epoch 42/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1778.3433 - val_loss: 1799.8390
# Epoch 43/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 1797.7149 - val_loss: 1799.6227
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 44/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1813.2173 - val_loss: 1799.5975
# Epoch 45/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1758.0689 - val_loss: 1799.5903
# Epoch 46/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1793.6932 - val_loss: 1799.5343
# Epoch 47/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 1775.1550 - val_loss: 1799.5291
# Epoch 48/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1765.0898 - val_loss: 1799.5092
# Epoch 49/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1854.7926 - val_loss: 1799.5071
# Epoch 50/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1783.7724 - val_loss: 1799.5004
# Epoch 51/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 1758.6443 - val_loss: 1799.4977
# Epoch 52/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1811.4095 - val_loss: 1799.4926
# Epoch 53/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 1799.7512 - val_loss: 1799.4977
# Epoch 54/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 1838.8954 - val_loss: 1799.4977
# Epoch 55/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 1771.8803 - val_loss: 1799.4977
# Epoch 56/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1814.2091 - val_loss: 1799.4977
# Epoch 57/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1809.6420 - val_loss: 1799.4998
# Epoch 58/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1861.4478 - val_loss: 1799.4982
# Epoch 59/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1801.0212 - val_loss: 1799.4994
# Epoch 60/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1757.8388 - val_loss: 1799.5018
# Epoch 61/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1817.1818 - val_loss: 1799.5020
# Epoch 62/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1779.8164 - val_loss: 1799.4998
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 63/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1803.4535 - val_loss: 1799.4998
# Epoch 64/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1780.4149 - val_loss: 1799.5022
# Epoch 65/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1783.2264 - val_loss: 1799.5070
# Epoch 66/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1810.5220 - val_loss: 1799.5074
# Epoch 67/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1786.2970 - val_loss: 1799.5087
# Epoch 68/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1798.9197 - val_loss: 1799.5087
# Epoch 69/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 1878.7995 - val_loss: 1799.5092
# Epoch 70/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1818.6278 - val_loss: 1799.5278
# Epoch 71/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 1798.6702 - val_loss: 1799.5280
# Epoch 72/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1853.7524 - val_loss: 1799.5280
# Restoring model weights from the end of the best epoch
# Epoch 00072: early stopping

# %%
plt.plot(CombinedModel.history.history['loss'])
plt.plot(CombinedModel.history.history['val_loss'])
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Mean Model (2nd Train) (Constant Loss Function)')
plt.legend(['Train', 'Validation'])
plt.show()
# Out:
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.

# %%
CheckPoint5 = ModelCheckpoint('models_GALAXIA/TrainingErrorBars2_{epoch:04d}.hdf5',
                             verbose=0,
                             save_best_only=False
                            )
ES5 = EarlyStopping(patience=20, verbose=True, restore_best_weights=True)
RLR5 = ReduceLROnPlateau(patience=10, min_lr=1e-5)
CSV_logger5 = CSVLogger(filename='logs/training_errorbars2.log', separator=',', append=False)

mycallbacks5 = [CheckPoint5, ES5, RLR5, CSV_logger5]
#mycallbacks5 = [ES5, RLR5]

# %%
ConfEst.trainable = True
MeanEst.trainable = False
CombinedModel.compile(loss=LikelihoodLossFunction,
                      optimizer='adam'
                     )

CombinedModel.fit_generator(TrainLoader,
                            validation_data=ValLoader,
                            epochs=1000,
                            callbacks = mycallbacks5
                 )
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 132ms/step - loss: 7.8936 - val_loss: 7.9409
# Epoch 2/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8478 - val_loss: 7.9350
# Epoch 3/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.9065 - val_loss: 7.9352
# Epoch 4/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8630 - val_loss: 7.9413
# Epoch 5/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.9091 - val_loss: 7.9380
# Epoch 6/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8982 - val_loss: 7.9359
# Epoch 7/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8849 - val_loss: 7.9369
# Epoch 8/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8966 - val_loss: 7.9395
# Epoch 9/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8614 - val_loss: 7.9388
# Epoch 10/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8970 - val_loss: 7.9336
# Epoch 11/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8961 - val_loss: 7.9316
# Epoch 12/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 7.8963 - val_loss: 7.9340
# Epoch 13/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 7.8828 - val_loss: 7.9379
# Epoch 14/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 7.8854 - val_loss: 7.9355
# Epoch 15/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8850 - val_loss: 7.9355
# Epoch 16/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.9231 - val_loss: 7.9341
# Epoch 17/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.9186 - val_loss: 7.9322
# Epoch 18/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.9031 - val_loss: 7.9342
# Epoch 19/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8781 - val_loss: 7.9404
# Epoch 20/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8722 - val_loss: 7.9403
# Epoch 21/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 7.8869 - val_loss: 7.9359
# Epoch 22/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 7.8880 - val_loss: 7.9355
# Epoch 23/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.9107 - val_loss: 7.9355
# Epoch 24/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 7.8793 - val_loss: 7.9355
# Epoch 25/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8704 - val_loss: 7.9356
# Epoch 26/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8868 - val_loss: 7.9362
# Epoch 27/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 7.8863 - val_loss: 7.9365
# Epoch 28/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 7.9115 - val_loss: 7.9364
# Epoch 29/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.8861 - val_loss: 7.9362
# Epoch 30/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 7.8713 - val_loss: 7.9357
# Epoch 31/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 7.8720 - val_loss: 7.9355
# Restoring model weights from the end of the best epoch
# Epoch 00031: early stopping

# %%
plt.plot(CombinedModel.history.history['loss'])
plt.plot(CombinedModel.history.history['val_loss'])
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Confidence Model (2nd Train) (Likelihood Loss Function)')
plt.legend(['Train', 'Validation'])
plt.show()
# Out:
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.

# %% [markdown]
# ## Third Training Iteration

# %%
CheckPoint6 = ModelCheckpoint('models/TrainingMean3_{epoch:04d}.hdf5',
                             verbose=0,
                             save_best_only=False
                            )
ES4 = EarlyStopping(patience=20, verbose=True, restore_best_weights=True)
RLR4 = ReduceLROnPlateau(patience=10, min_lr=1e-5, verbose=True)
CSV_logger6 = CSVLogger(filename='logs/training_mean3.log', separator=',', append=False)

mycallbacks6 = [CheckPoint6, ES4, RLR4, CSV_logger6]
#mycallbacks4 = [ES4, RLR4]

# %%
ConfModel.trainable = False
MeanModel.trainable = True
CombinedModel.compile(loss=ConstantLikelihoodLossFunction,
                      optimizer='adam'
                     )
history = CombinedModel.fit(X_train,y_train,
                  validation_data=(X_val, y_val),
                  epochs=1000,
                  batch_size=10000,
                  callbacks = mycallbacks6
                 )

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Mean Model (3rd Train) (Constant Loss Function)')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
CheckPoint7 = ModelCheckpoint('models/TrainingErrorBars3_{epoch:04d}.hdf5',
                             verbose=0,
                             save_best_only=False
                            )
ES5 = EarlyStopping(patience=20, verbose=True, restore_best_weights=True)
RLR5 = ReduceLROnPlateau(patience=10, min_lr=1e-5)
CSV_logger7 = CSVLogger(filename='logs/training_errorbars3.log', separator=',', append=False)

mycallbacks7 = [CheckPoint7, ES5, RLR5, CSV_logger7]
#mycallbacks5 = [ES5, RLR5]

# %%
ConfModel.trainable = True
MeanModel.trainable = False
CombinedModel.compile(loss=LikelihoodLossFunction,
                      optimizer='adam'
                     )

history = CombinedModel.fit(X_train,y_train,
                  validation_data=(X_val, y_val),
                  epochs=1000,
                  batch_size=10000,
                  callbacks = mycallbacks7,
                 )

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Confidence Model (3rd Train) (Likelihood Loss Function)')
plt.legend(['Train', 'Validation'])
plt.show()

# %% [markdown]
# ## Train Both

# %%
CheckPoint3 = ModelCheckpoint('models_GALAXIA/TrainingBoth_{epoch:04d}.hdf5',
                             verbose=0,
                             save_best_only=False
                            )
ES3 = EarlyStopping(patience=20, verbose=True, restore_best_weights=True)
RLR3 = ReduceLROnPlateau(patience=10, min_lr=1e-5)
CSV_logger3 = CSVLogger(filename='logs/training_both.log', separator=',', append=False)

mycallbacks3 = [CheckPoint3, ES3, RLR3, CSV_logger3]
#mycallbacks3 = [ES3, RLR3]

# %%
ConfEst.trainable = True
MeanEst.trainable = True
CombinedModel.compile(loss=LikelihoodLossFunction,
                      optimizer='adam'
                     )

CombinedModel.fit_generator(TrainLoader,
                            validation_data=ValLoader,
                            epochs=1000,
                            callbacks = mycallbacks3
                 )
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 176ms/step - loss: 7.8827 - val_loss: 7.9393
# Epoch 2/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 7.8912 - val_loss: 7.9360
# Epoch 3/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8557 - val_loss: 7.9394
# Epoch 4/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8650 - val_loss: 7.9425
# Epoch 5/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8700 - val_loss: 7.9389
# Epoch 6/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 7.8695 - val_loss: 7.9370
# Epoch 7/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8571 - val_loss: 7.9384
# Epoch 8/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 7.8705 - val_loss: 7.9404
# Epoch 9/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 7.8677 - val_loss: 7.9405
# Epoch 10/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8591 - val_loss: 7.9403
# Epoch 11/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8770 - val_loss: 7.9393
# Epoch 12/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8898 - val_loss: 7.9354
# Epoch 13/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8775 - val_loss: 7.9350
# Epoch 14/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8406 - val_loss: 7.9375
# Epoch 15/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8687 - val_loss: 7.9371
# Epoch 16/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8317 - val_loss: 7.9342
# Epoch 17/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8711 - val_loss: 7.9380
# Epoch 18/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8696 - val_loss: 7.9364
# Epoch 19/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8728 - val_loss: 7.9369
# Epoch 20/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.9028 - val_loss: 7.9355
# Epoch 21/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8500 - val_loss: 7.9359
# Epoch 22/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8871 - val_loss: 7.9355
# Epoch 23/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8756 - val_loss: 7.9354
# Epoch 24/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8786 - val_loss: 7.9344
# Epoch 25/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 7.8892 - val_loss: 7.9325
# Epoch 26/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 7.8529 - val_loss: 7.9330
# Epoch 27/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8428 - val_loss: 7.9394
# Epoch 28/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8337 - val_loss: 7.9375
# Epoch 29/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8810 - val_loss: 7.9325
# Epoch 30/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8533 - val_loss: 7.9307
# Epoch 31/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 7.8655 - val_loss: 7.9313
# Epoch 32/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8560 - val_loss: 7.9298
# Epoch 33/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8846 - val_loss: 7.9293
# Epoch 34/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.9081 - val_loss: 7.9277
# Epoch 35/1000
# 4/4 [==============================] - 0s 70ms/step - loss: 7.8725 - val_loss: 7.9283
# Epoch 36/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 7.8460 - val_loss: 7.9337
# Epoch 37/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 7.8671 - val_loss: 7.9330
# Epoch 38/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8731 - val_loss: 7.9317
# Epoch 39/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8521 - val_loss: 7.9296
# Epoch 40/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 7.8595 - val_loss: 7.9283
# Epoch 41/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8634 - val_loss: 7.9277
# Epoch 42/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8648 - val_loss: 7.9234
# Epoch 43/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8581 - val_loss: 7.9232
# Epoch 44/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8501 - val_loss: 7.9269
# Epoch 45/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 7.9080 - val_loss: 7.9278
# Epoch 46/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8400 - val_loss: 7.9229
# Epoch 47/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8851 - val_loss: 7.9248
# Epoch 48/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 7.8812 - val_loss: 7.9266
# Epoch 49/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8686 - val_loss: 7.9278
# Epoch 50/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 7.8575 - val_loss: 7.9253
# Epoch 51/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8667 - val_loss: 7.9220
# Epoch 52/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8383 - val_loss: 7.9258
# Epoch 53/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8535 - val_loss: 7.9321
# Epoch 54/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 7.8683 - val_loss: 7.9276
# Epoch 55/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8334 - val_loss: 7.9272
# Epoch 56/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 7.8994 - val_loss: 7.9292
# Epoch 57/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8590 - val_loss: 7.9273
# Epoch 58/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8716 - val_loss: 7.9264
# Epoch 59/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 7.8474 - val_loss: 7.9263
# Epoch 60/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8509 - val_loss: 7.9306
# Epoch 61/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 7.8529 - val_loss: 7.9292
# Epoch 62/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 7.9104 - val_loss: 7.9277
# Epoch 63/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 7.8779 - val_loss: 7.9268
# Epoch 64/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8545 - val_loss: 7.9259
# Epoch 65/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8460 - val_loss: 7.9257
# Epoch 66/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8433 - val_loss: 7.9257
# Epoch 67/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8658 - val_loss: 7.9258
# Epoch 68/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 7.8723 - val_loss: 7.9258
# Epoch 69/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 7.8429 - val_loss: 7.9258
# Epoch 70/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 7.8306 - val_loss: 7.9261
# Epoch 71/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 7.8690 - val_loss: 7.9257
# Restoring model weights from the end of the best epoch
# Epoch 00071: early stopping

# %%
plt.plot(CombinedModel.history.history['loss'])
plt.plot(CombinedModel.history.history['val_loss'])
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Both Models (Likelihood Loss Function)')
plt.legend(['Train', 'Validation'])
plt.savefig('Loss_Plot_Iterate.png')
plt.show()
# Out:
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\\times' [U+d7], substituting with a dummy symbol.

# %%
CombinedModel.save_weights("models_GALAXIA/ModelWeights.h5")

# %%
 def plot_validation(i,type1):   
    y_low = -700
    y_high = 700
    plt.figure(figsize=(12, 12))
    gs0 = gridspec.GridSpec(3, 3, hspace=0.3, wspace=0.3)

    from matplotlib.colors import LogNorm
    plt.subplot(gs0[3])
    plt.hist2d( test_preds[:,1],test_preds[:,0], bins=40,norm = LogNorm())
    clb1 = plt.colorbar()
    clb1.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel('$\sigma$',labelpad=-10)

    plt.subplot(gs0[4])
    sc = plt.scatter(y_val[:,0], test_preds[:,0], c =test_preds[:,1], label = 'data',marker = '.',cmap=plt.cm.YlOrRd)
    x1 = np.linspace(y_low,y_high,1000)
    y1 = x1
    plt.plot(x1,y1,'k--')
    plt.xlim([y_low, y_high])
    plt.ylim([y_low,y_high])
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel(r'$v_{\rm{los}}^{\rm{meas}}$')
    clb2 = plt.colorbar(sc)
    clb2.set_label('$\sigma$', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.clim(0,750)

    plt.subplot(gs0[2])
    hb = plt.hexbin(y_val[:,0], test_preds[:,0],gridsize=80, norm = LogNorm())
    x1 = np.linspace(np.min(y_val[:,0]),np.max(y_val[:,0]),1000)
    y1 = x1
    plt.plot(x1,y1,'k--')
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel(r'$v_{\rm{los}}^{\rm{meas}}$')
    clb3 = plt.colorbar(hb)
    clb3.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)


    plt.subplot(gs0[5])
    sc = plt.scatter(y_val[:,0], test_preds[:,0], c =test_preds[:,1], label = 'data',marker = '.',cmap=plt.cm.YlOrRd)
    x1 = np.linspace(y_low,y_high,1000)
    y1 = x1
    plt.plot(x1,y1,'k--')
    plt.xlim([y_low, y_high])
    plt.ylim([y_low,y_high])
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel(r'$v_{\rm{los}}^{\rm{meas}}$')
    clb4 = plt.colorbar(sc)
    clb4.set_label('$\sigma$\n(saturated)', labelpad=-25, y=1.15, rotation=0,fontsize=10)
    plt.clim(0,200)

    plt.subplot(gs0[6])
    plt.hist2d(X_val[:,2], test_preds[:,1], bins=40, norm = LogNorm())
    clb5 = plt.colorbar()
    clb5.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.xlabel('Distance',fontsize = 12)
    plt.ylabel('$\sigma$',labelpad=-5)

    plt.subplot(gs0[1])
    plotrange = np.linspace(-5,5,1000)
    diff_hist = np.divide(np.subtract(test_preds[:,0],y_val[:,0]),test_preds[:,1])
    mean_diffs, mean_stds = np.mean(diff_hist), np.std(diff_hist)
    plt.hist(diff_hist,bins=20, range=(-5,5), histtype='step',color = 'lightseagreen',linewidth = 1.5, density = True)
    plt.plot(plotrange, norm.pdf(plotrange, mean_diffs, mean_stds),color = 'darkorange', linestyle = '--', linewidth = 2.5,label = 'normal fit')
    plt.yscale('log')
    plt.legend(loc = "upper right",prop={'size': 8})
    plt.xlabel(r'$(v_{\rm{los}}^{\rm{pred}} - v_{\rm{los}}^{\rm{meas}})/\sigma$',labelpad=-5)
    
    plt.subplot(gs0[7])
    diff_hist_err = np.subtract(test_preds[:,0],y_val[:,0])
    plt.hist2d(test_preds[:,1],diff_hist_err, bins=40,norm = LogNorm())
    clb6 = plt.colorbar()
    clb6.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.plot(x1,y1,'k--')
    plt.ylabel(r'$(v_{\rm{los}}^{\rm{pred}} - v_{\rm{los}}^{\rm{meas}})$',labelpad=-5)
    plt.xlabel('$\sigma$',labelpad=-5)

    plt.subplot(gs0[0])
    plt.hist(y_val[:,0], bins=25, range=(y_low,y_high), histtype='step', edgecolor = 'skyblue', color= 'skyblue', fill = True, label = 'val' )
    plt.hist(test_preds[:,0], bins=25, range=(y_low,y_high), histtype='step',color = 'blue', label = 'predicted')
    plt.xlabel(r'$v_{\rm{los}}$', labelpad =-2)
    plt.title('Validation set, Train '+type1+', Epoch '+str(i)+', 20 bins',fontsize=14)
    plt.yscale('log')
    plt.legend(loc = "upper right",prop={'size': 10})
    
    plt.savefig('plots'+type1+'/'+'train'+type1+'_'+str(i)+'.png')
    clb1.remove()
    clb2.remove()
    clb3.remove()
    clb4.remove()
    clb5.remove()
    clb6.remove()

# %% [markdown]
# #### Plotting First Training

# %%
traininmean = [file for file in os.listdir('models/')
               if file.startswith('TrainingMean_')]
traininmean = sorted(traininmean)[1::10]

# %%
# %%capture
for i, mfile in enumerate(traininmean):
    CombinedModel.load_weights('models/' + mfile)
    
    test_preds = CombinedModel.predict(X_val)

    
    plot_validation(i*10,'Mean1');

# %%
traininerror = [file for file in os.listdir('models/')
               if file.startswith('TrainingErrorBars_')]
traininerror = sorted(traininerror)[0::20]

# %%
# %%capture
for i_err, mfile_err in enumerate(traininerror):
    CombinedModel.load_weights('models/' + mfile_err)
    
    test_preds = CombinedModel.predict(X_val)

    
    plot_validation(i_err*20,'Error1');

# %% [markdown]
# #### Plotting Second Training

# %%
traininmean2 = [file for file in os.listdir('models/')
               if file.startswith('TrainingMean2')]
traininmean2 = sorted(traininmean2)[0::10]

# %%
# %%capture
for i, mfile in enumerate(traininmean2):
    CombinedModel.load_weights('models/' + mfile)
    
    test_preds = CombinedModel.predict(X_val)

    
    plot_validation(i*10,'Mean2');

# %%
traininerror2 = [file for file in os.listdir('models/')
               if file.startswith('TrainingErrorBars2')]
traininerror2 = sorted(traininerror2)[0::20]

# %%
# %%capture
for i_err, mfile_err in enumerate(traininerror2):
    CombinedModel.load_weights('models/' + mfile_err)
    
    test_preds = CombinedModel.predict(X_val)

    
    plot_validation(i_err*20,'Error2');

# %% [markdown]
# #### Plotting Third Training

# %%
traininmean3 = [file for file in os.listdir('models/')
               if file.startswith('TrainingMean3')]
traininmean3 = sorted(traininmean3)[0::10]

# %%
# %%capture
for i, mfile in enumerate(traininmean3):
    CombinedModel.load_weights('models/' + mfile)
    
    test_preds = CombinedModel.predict(X_val)

    
    plot_validation(i*10,'Mean3');

# %%
traininerror3 = [file for file in os.listdir('models/')
               if file.startswith('TrainingErrorBars3')]
traininerror3 = sorted(traininerror3)[0::20]

# %%
# %%capture
for i_err, mfile_err in enumerate(traininerror3):
    CombinedModel.load_weights('models/' + mfile_err)
    
    test_preds = CombinedModel.predict(X_val)

    
    plot_validation(i_err*20,'Error3');

# %% [markdown]
# #### Plot results of training both

# %%
traininboth = [file for file in os.listdir('models/')
               if file.startswith('TrainingBoth')]
traininboth = sorted(traininboth)[1::10]

# %%
# %%capture
for i_both, mfile_both in enumerate(traininboth):
    CombinedModel.load_weights('models/' + mfile_both)
    
    test_preds = CombinedModel.predict(X_val)

    
    plot_validation(i_both*10,'Both');

# %%
y_low = -250
y_high = 250

# %% [markdown]
# ### Evaluate the Test Set

# %%
#CombinedModel.load_weights('G_train_2it_50k_nn_norvscale_lbdpmrapmdec/models_GALAXIA/' + 'TrainingMean_0308.hdf5')
test_preds_2 = CombinedModel.predict_generator(TestLoader)

plt.figure()
plt.hist((data_test_scaled['radial_velocity']).values, bins=100, range=(y_low,y_high), histtype='step', edgecolor = 'skyblue', color= 'skyblue', fill = True, label = 'test' , density = True)
plt.hist(test_preds_2[:,0], bins=100, range=(y_low,y_high), histtype='step',color = 'blue', label = 'predicted', density = True)
plt.xlabel('Vr')
plt.ylabel('Stars')
plt.title('Test set - simulated data')
#plt.yscale('log')
plt.legend(loc = "upper right")
plt.show()

# %%
print(y_high)
# Out:
# 250

# %% [markdown]
# ## Going to use Monte Carlo simulations to predict errorbars.

# %%
mc_vr_pred_list = []
bin_values_list = []
min_array = []
max_array = []
mean_array = []
for mc_i in range(0,1000):
    #print(mc_i)
    mc_vr_pred = []
    for star_i in range(0,np.size(y_test)):
        #mc_vr_pred.append(np.mean([np.random.normal(test_preds_2[star_i,0],test_preds_2[star_i,1]) for _ in range(1000)]))
        mc_vr_pred.append(np.random.normal(test_preds_2[star_i,0],test_preds_2[star_i,1]))
    mc_vr_pred_list.append(mc_vr_pred)
    n, bins, patches = plt.hist(mc_vr_pred, bins=20, range=(y_low,y_high), histtype='step')
    plt.xlabel('Vr Monte Carlo')
    plt.yscale('log')
    bin_values_list.append(n)
bin_values_list_arr = np.array(bin_values_list)    
max_array = bin_values_list_arr.max(axis=0)
min_array = bin_values_list_arr.min(axis=0) 
mean_array = bin_values_list_arr.mean(axis=0)
y_error = [min_array,max_array]
print(np.shape(y_error))

# %%
plt.figure()
hist_test, bins_test, patches_test = plt.hist(y_test, bins=20, range=(y_low,y_high), histtype='step', edgecolor = 'skyblue', color= 'skyblue', fill = True, label = 'test' , zorder = 0)
#plt.hist(bins_test[:-1], bins_test, weights=max_array,color = 'green')
#plt.hist(bins_test[:-1], bins_test, weights=min_array,color = 'yellow')
bin_centers_test = (bins_test[1:]+bins_test[:-1])/2
plt.fill_between(bin_centers_test,min_array, max_array,label = 'MC spread',color = 'orange', zorder = 10)

plt.hist(test_preds_2[:,0], bins=20, range=(y_low,y_high), histtype='step',color = 'blue', label = 'predicted', zorder = 20)
print(y_low,y_high)
plt.xlabel(r'$v_{\rm{los}}$')
plt.title('Test set - simulated data')
plt.yscale('log')
plt.legend(loc = "upper right",prop={'size': 10})
plt.savefig('MC_100trials_8000stars_noavg.png')
plt.show()

# %%
 def plot_test():   
    y_low = -250
    y_high = 250
    plt.figure(figsize=(12, 12))
    gs0 = gridspec.GridSpec(3, 3, hspace=0.3, wspace=0.3)

    from matplotlib.colors import LogNorm
    plt.subplot(gs0[3])
    plt.hist2d(test_preds_2[:,1],test_preds_2[:,0], bins=40,norm = LogNorm())
    clb1 = plt.colorbar()
    clb1.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel('$\sigma$',labelpad=-5)
    

    plt.subplot(gs0[4])
    sc = plt.scatter((data_test_scaled['radial_velocity']).values, test_preds_2[:,0], c =test_preds_2[:,1], label = 'data',marker = '.',cmap=plt.cm.YlOrRd)
    x1 = np.linspace(y_low,y_high,1000)
    y1 = x1
    plt.plot(x1,y1,'k--')
    plt.xlim([y_low, y_high])
    plt.ylim([y_low,y_high])
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel(r'$v_{\rm{los}}^{\rm{meas}}$')
    clb2 = plt.colorbar(sc)
    clb2.set_label('$\sigma$', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.clim(0,250)

    plt.subplot(gs0[2])
    hb = plt.hexbin((data_test_scaled['radial_velocity']).values, test_preds_2[:,0],gridsize=100, norm = LogNorm(),extent=[-150, 150, -150, 150])
    #x1 = np.linspace(np.min((data_test_scaled['radial_velocity']).values),np.max((data_test_scaled['radial_velocity']).values),1000)
    x1 = np.linspace(-150,150,1000)
    y1 = x1
    plt.plot(x1,y1,'k--')
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel(r'$v_{\rm{los}}^{\rm{meas}}$')
    clb3 = plt.colorbar(hb)
    clb3.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)


    plt.subplot(gs0[5])
    sc = plt.scatter((data_test_scaled['radial_velocity']).values, test_preds_2[:,0], c =test_preds_2[:,1], label = 'data',marker = '.',cmap=plt.cm.YlOrRd)
    x1 = np.linspace(y_low,y_high,1000)
    y1 = x1
    plt.plot(x1,y1,'k--')
    plt.xlim([y_low, y_high])
    plt.ylim([y_low,y_high])
    plt.ylabel(r'$v_{\rm{los}}^{\rm{pred}}$',labelpad=-10)
    plt.xlabel(r'$v_{\rm{los}}^{\rm{meas}}$')
    clb4 = plt.colorbar(sc)
    clb4.set_label('$\sigma$\n(saturated)', labelpad=-25, y=1.15, rotation=0,fontsize=10)
    plt.clim(0,200)

    plt.subplot(gs0[6])
    dist_hist = np.divide(np.ones_like((data_test['parallax']).values),(data_test['parallax']).values)
    plt.hist2d(dist_hist, test_preds_2[:,1], bins=40, norm = LogNorm())
    clb5 = plt.colorbar()
    clb5.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.xlabel('Distance (kpc)',fontsize = 12)
    plt.ylabel('$\sigma$',labelpad=-5)

    plt.subplot(gs0[1])
    plotrange = np.linspace(-5,5,1000)
    diff_hist = np.divide(np.subtract(test_preds_2[:,0],(data_test_scaled['radial_velocity']).values),test_preds_2[:,1])
    mean_diffs, mean_stds = np.mean(diff_hist), np.std(diff_hist)
    plt.hist(diff_hist,bins=20, range=(-5,5), histtype='step',color = 'lightseagreen',linewidth = 1.5, density = True)
    plt.plot(plotrange, norm.pdf(plotrange, mean_diffs, mean_stds),color = 'darkorange', linestyle = '--', linewidth = 2.5,label = 'normal fit')
    plt.yscale('log')
    plt.legend(loc = "upper right",prop={'size': 8})
    plt.xlabel(r'$(v_{\rm{los}}^{\rm{pred}} - v_{\rm{los}}^{\rm{meas}})/\sigma$',labelpad=-5)
    
    plt.subplot(gs0[7])
    plt.hist2d((data_test['l']).values,test_preds_2[:,1], bins=40,norm = LogNorm())
    clb6 = plt.colorbar()
    clb6.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.plot(x1,y1,'k--')
    plt.xlabel(r'$l$',labelpad=-3)
    plt.ylabel('$\sigma$',labelpad=-5)
    
    plt.subplot(gs0[8])
    plt.hist2d((data_test['b']).values,test_preds_2[:,1], bins=40,norm = LogNorm())
    clb6 = plt.colorbar()
    clb6.set_label('Density', labelpad=-25, y=1.08, rotation=0,fontsize=10)
    plt.plot(x1,y1,'k--')
    plt.xlabel(r'$b$',labelpad=-3)
    plt.ylabel('$\sigma$',labelpad=-5)

    plt.subplot(gs0[0])
    plt.hist((data_test_scaled['radial_velocity']).values, bins=100, range=(y_low,y_high), histtype='step', edgecolor = 'skyblue', color= 'skyblue', fill = True, label = 'test', density = True )
    plt.hist(test_preds_2[:,0], bins=100, range=(y_low,y_high), histtype='step',color = 'blue', label = 'predicted', density = True)
    plt.xlabel(r'$v_{\rm{los}}$', labelpad =-2)
    plt.title('Test set - simulated data, 50 bins',fontsize=14)
    #plt.yscale('log')
    plt.legend(loc = "upper right",prop={'size': 10})
    plt.savefig('plots_test_2it_nn_50k.png')
    clb1.remove()
    clb2.remove()
    clb3.remove()
    clb4.remove()
    clb5.remove()
    clb6.remove()

# %%
plot_test()

# %% [markdown]
# ##### Going to try to find original indices of points with low error in train, validation, and test & retrain without those

# %%
print(np.max(test_preds_2[:,1]))

 # min_cl = np.nanmin(code_lengths)
  #  min_k = Ks[code_lengths.index(min_cl)] 
list_pmra_test_err_lt65 = []   
list_rv_test_err_lt65 = [y_test[i,0] for i in range(len(test_preds_2[:,1])) if test_preds_2[i,1] < 90]
print(len(list_rv_test_err_lt65))
#now need indices of these values in data
indices = []
for i in range(len(list_rv_test_err_lt65)):
    indices.append(data[data['radial_velocity']==(list_rv_test_err_lt65[i])].index[0])

# %%
CombinedModel.load_weights('models/' + 'TrainingBoth_0138.hdf5')
test_preds_train = CombinedModel.predict(X_train)

list_rv_train_err_lt65 = [y_train[i,0] for i in range(len(test_preds_train[:,1])) if test_preds_train[i,1] < 90]
for i in range(len(list_rv_train_err_lt65)):
    indices.append(data[data['radial_velocity']==(list_rv_train_err_lt65[i])].index[0])

# %%
test_preds_val = CombinedModel.predict(X_val)

list_rv_val_err_lt65 = [y_val[i,0] for i in range(len(test_preds_val[:,1])) if test_preds_val[i,1] < 90]
for i in range(len(list_rv_val_err_lt65)):
    indices.append(data[data['radial_velocity']==(list_rv_val_err_lt65[i])].index[0])

# %%
np.save('data_indices_error_lt100_50k',indices)

# %%
print(np.shape(indices))
